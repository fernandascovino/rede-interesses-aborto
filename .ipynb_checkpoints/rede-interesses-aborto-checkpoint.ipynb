# %% [markdown]
# ### Rede de insteresses dos deputados

# %% [markdown]
# #### OBJETIVO
#
# ---
#
# Entender quem são os atores centrais na Câmara na discussão sobre o *aborto*.
#
# #### METODOLOGIA
#
# ---
#
# A rede consiste num multigrafo $G = \{V,E\}$, no qual:
#
# * $V = \{d_{i}\}$, é o conjunto dos deputados $d_{i}$.
# * $E = \{\{d_{i}, d_{j}\}\}$, $i \neq j$, é o conjunto das relações entre deputados.
# Cada aresta representa uma proposição em que ambos os deputados atuaram, ou seja, estão presentes no despacho das tramitações dessa proposição.
#
# O caminho entre os nós pode ser entendido como o grau de "proximidade" da discussão na qual dois deputados estão envolvidos, supondo que os deputados atuam em proposições que condizem com seus próprios interesses.
#
# Algumas propriedades da rede são:
#
# * Seja $n$ o total de deputados, $| V | = n$, e $m$ o total de tramitações das proposições. Então, $| E | \leq m^{n}$.
#
# * Seja $\sigma_{jk}$ o menor caminho do nó $d_{j}$ ao $d_{k}$. Então, $\sum_{j\neq k}{\sigma_{d_{j}d_{k}}} = \frac{n(n-1)}{2}$
#
# Calculamos a intermediação (*betweness*) da rede para determinar quem mais influencia nas pautas sobre o tema.
#
# Para cada deputado, sua intermediação consiste na razão do número de menores caminho que passam por ele pelo total, ou seja:
#
# $g(d_{i}) = \sum_{j\neq k\neq i}\frac{\sigma_{d_{j}d_{k}}(d_{i})}{\sigma_{d_{j}d_{k}}} =
# \frac{2 \sum_{j\neq k\neq i}{\sigma_{d_{j}d_{k}(d_{i})}}}{n(n-1)}$
#
# onde $\sigma_{jk}$ é o menor caminho do nó $d_{j}$ ao $d_{k}$.
#
#
# #### Referências
#
# ---
# [Intermediação - Wikipédia](https://pt.wikipedia.org/wiki/Intermedia%C3%A7%C3%A3o)

# %% [markdown]
# 2. Ver se existem grupos específicos que dominam essas pautas (através do coeficiente de agrupamento local).

# %%
# SERVER CONNECTION
from sqlalchemy import create_engine
import yaml

server = yaml.load(open('db-links.yaml', 'r'))
con = create_engine(server['postgretic'])

# DATA ANALYSIS & VIZ TOOLS
from copy import deepcopy
import pandas as pd

pd.options.display.max_columns = 999

import plotly
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)

# %pylab inline
pylab.rcParams['figure.figsize'] = (12, 12)

# FILES STORAGE
import os
cwd = os.getcwd()

RAW_DATA = cwd+'/raw_data/' # put primary data here
DATA = cwd+'/data/' # put processed data here

# BASIC INFOS
from datetime import datetime as dt
i = round((dt.now().year - 2003)/4+0.5)
period = list(range(0,i))

legislaturas = {}
for x in period:
    
    t = ('{}-01-31'.format(2003+4*x), '{}-02-01'.format(2007+4*x))
    legislaturas[t] = 52+x
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Bases de dados

# %% [markdown]
# A base `deputados`contém as informações dos deputados desde a 52ª legislatura.

# %%
deputados = pd.read_csv(RAW_DATA+'deputados.csv', index_col=0)
deputados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2481 entries, 0 to 2480
# Data columns (total 16 columns):
# id                      2481 non-null int64
# capnum                  2481 non-null int64
# datacaptura             2481 non-null object
# idecadastro             2481 non-null int64
# numlegislatura          2481 non-null int64
# nomeparlamentar         2481 non-null object
# sexo                    2481 non-null object
# profissao               2131 non-null object
# legendapartidoeleito    2481 non-null object
# ufeleito                2481 non-null object
# condicao                2481 non-null object
# situacaomandato         2481 non-null object
# matricula               2481 non-null int64
# gabinete                2481 non-null int64
# anexo                   2481 non-null int64
# fone                    513 non-null object
# dtypes: int64(7), object(9)
# memory usage: 329.5+ KB

# %%
deputados.head(3)
# Out:
#      id  capnum          datacaptura  idecadastro  numlegislatura  \
# 0  2211       2  2015-11-02 13:14:39       141542              55
# 1  2215       2  2015-11-02 13:14:39       178874              55
# 2   324       2  2015-11-02 13:14:39       160538              54
#
#   nomeparlamentar sexo                                   profissao  \
# 0   SÉRGIO MORAES    M                                 COMERCIANTE
# 1  SERGIO VIDIGAL    M                                         NaN
# 2       BOHN GASS    M  Agricultor Familiar, Professor de História
#
#   legendapartidoeleito ufeleito condicao situacaomandato  matricula  gabinete  \
# 0                  PTB       RS  Titular    Em Exercício        512       258
# 1                  PDT       ES  Titular    Em Exercício        283       812
# 2                   PT       RS  Titular    Em Exercício        499         0
#
#    anexo       fone
# 0      4  3215-5258
# 1      4  3215-5812
# 2      0        NaN

# %%
deputados[deputados['situacaomandato'] == 'Em Exercício']['numlegislatura'].value_counts()
# Out:
# 53    513
# 55    512
# 54    512
# 52    510
# Name: numlegislatura, dtype: int64

# %% [markdown]
# A base `props_aborto`contém a descrição das proposições sobre aborto já apresentadas na Câmara.

# %%
props_aborto = pd.read_csv(RAW_DATA+'props_aborto_teor.csv')
props_aborto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 15 columns):
# Proposições             68 non-null object
# Classe                  68 non-null object
# Apreciação              68 non-null object
# Regime de Tramitação    68 non-null object
# Natureza                68 non-null object
# Ementa                  68 non-null object
# Explicação              38 non-null object
# Autor                   68 non-null object
# UF                      68 non-null object
# Partido                 68 non-null object
# Apresentação            68 non-null object
# Ano                     68 non-null int64
# Unnamed: 12             55 non-null object
# Situação                68 non-null object
# Link                    68 non-null object
# dtypes: int64(1), object(14)
# memory usage: 8.0+ KB

# %%
props_aborto.head(3)
# Out:
#      Proposições  Classe Apreciação        Regime de Tramitação Natureza  \
# 0   PL 7122/2017  Aborto   Plenário  Prioridade (151, II, RICD)  A favor
# 1  PDC 1487/2014  Aborto   Plenário  Ordinária (151, III, RICD)   Contra
# 2  PDC 1490/2014  Aborto   Plenário  Ordinária (151, III, RICD)   Contra
#
#                                               Ementa  \
# 0  Dispõe sobre a concessão de licença e de salár...
# 1  Susta a eficácia da Portaria nº 415, de 21 de ...
# 2  Susta a Portaria 415, de 21 de maio de 2014, "...
#
#                                          Explicação           Autor  UF  \
# 0  Altera o Decreto-Lei nº 5.452, de 1943 e a Lei...  Luciano Ducci  PR
# 1                                                NaN  Eduardo Cunha  RJ
# 2                                                NaN    Andre Moura  SE
#
#   Partido Apresentação   Ano Unnamed: 12  \
# 0     PSB    3/15/2017  2017    Apensada
# 1    PMDB    5/27/2014  2014        Raiz
# 2     PSC    5/28/2014  2014        Raiz
#
#                                             Situação  \
# 0  Aguardando Criação de Comissão Temporária pela...
# 1                                  Pronta para Pauta
# 2                             Tramitando em Conjunto
#
#                                                Link
# 0  http://www2.camara.gov.br/proposicoesWeb/ficha...
# 1  http://www2.camara.gov.br/proposicoesWeb/ficha...
# 2  http://www2.camara.gov.br/proposicoesWeb/ficha...

# %%
props_aborto['Apresentação'] = pd.to_datetime(props_aborto['Apresentação'])

# %%
print(props_aborto['Apresentação'].min())
print(props_aborto['Apresentação'].max())
# Out:
# 1977-11-10 00:00:00
# 2017-03-15 00:00:00

# %%
props_aborto['Proposições'].values
# Out:
# array(['PL 7122/2017', 'PDC 1487/2014', 'PDC 1490/2014', 'PDC 1757/2005',
#        'PDC 1832/2005', 'PDC 2840/2010', 'PDC 42/2007', 'PDC 467/2000',
#        'PDC 565/2012', 'PDC 566/2012', 'PDC 737/1998', 'PEC 164/2012',
#        'PEC 25/1995', 'PEC 303/2008', 'PEC 408/2005', 'PEC 553/2002',
#        'PEC 571/2002', 'PEC 62/2003', 'PL 1008/1988', 'PL 1035/1991',
#        'PL 1085/2011', 'PL 1091/2003', 'PL 1097/1991', 'PL 1104/1991',
#        'PL 1107/1991', 'PL 1135/1991', 'PL 1190/2011', 'PL 1459/2003',
#        'PL 1522/2015', 'PL 1545/2011', 'PL 176/1995', 'PL 1763/2007',
#        'PL 20/1991', 'PL 2059/2003', 'PL 2155/2007', 'PL 2423/1989',
#        'PL 2433/2007', 'PL 2438/1989', 'PL 244/1983', 'PL 2690/2007',
#        'PL 2852/2000', 'PL 3039/2015', 'PL 3166/1992', 'PL 3207/2008',
#        'PL 3348/2000', 'PL 3609/1993', 'PL 3673/2008', 'PL 3748/2008',
#        'PL 3783/2008', 'PL 3872/1989', 'PL 3983/2015', 'PL 4396/2016',
#        'PL 4403/2004', 'PL 4474/1977', 'PL 4641/2016', 'PL 4642/2016',
#        'PL 4646/2016', 'PL 4703/1998', 'PL 478/2007', 'PL 4880/2016',
#        'PL 489/2007', 'PL 4917/2001', 'PL 499/1988', 'PL 5058/2005',
#        'PL 5069/2013', 'PL 5166/2005', 'PL 5617/2016', 'PL 567/1983'], dtype=object)

# %% [markdown]
# A base `tramitacoes_aborto` contém as tramitações referentes às proposições acima.

# %%
tramitacoes_aborto = pd.read_csv(RAW_DATA+'tramitacoes_aborto.csv', index_col=0)
tramitacoes_aborto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1254 entries, 0 to 1253
# Data columns (total 25 columns):
# level_0                                    1254 non-null int64
# index                                      1254 non-null int64
# idProposicao                               1254 non-null int64
# ementa                                     1254 non-null object
# situacao                                   1254 non-null object
# numero                                     1254 non-null int64
# ano                                        1254 non-null int64
# tipo                                       1254 non-null object
# ultimaAcao_tramitacao_codOrgao             1254 non-null int64
# ultimaAcao_tramitacao_orgao                1254 non-null object
# ultimaAcao_tramitacao_descricao            1254 non-null object
# ultimaAcao_tramitacao_data                 1254 non-null object
# ultimaAcao_tramitacao_ordemDeTramitacao    1254 non-null int64
# andamento_tramitacao_codOrgao              1254 non-null int64
# andamento_tramitacao_Orgao                 1254 non-null object
# andamento_tramitacao_descricao             1254 non-null object
# andamento_tramitacao_inteiroTeor           564 non-null object
# andamento_tramitacao_codReuniao            100 non-null float64
# andamento_tramitacao_data                  1254 non-null object
# andamento_tramitacao_ordemDeTramitacao     1254 non-null int64
# data_captura                               1254 non-null object
# unique_id                                  1254 non-null int64
# ordem_tramitacao                           1254 non-null int64
# next_id                                    1187 non-null float64
# previous_id                                1187 non-null float64
# dtypes: float64(3), int64(11), object(11)
# memory usage: 254.7+ KB

# %%
tramitacoes_aborto['nomeProposicao'] = tramitacoes_aborto['tipo'].map(str) + ' ' + tramitacoes_aborto['numero'].map(str) + '/' + tramitacoes_aborto['ano'].map(str)

# %%
tramitacoes_aborto = tramitacoes_aborto[['idProposicao', 'nomeProposicao', 'andamento_tramitacao_descricao', 'andamento_tramitacao_data', 'unique_id']]
tramitacoes_aborto.head()
# Out:
#    idProposicao nomeProposicao  \
# 0        484558  PDC 2840/2010
# 1        484558  PDC 2840/2010
# 2        484558  PDC 2840/2010
# 3        484558  PDC 2840/2010
# 4        484558  PDC 2840/2010
#
#                       andamento_tramitacao_descricao  \
# 0  Encerramento automático do Prazo de Recurso. N...
# 1  Devolvido ao Autor, nos termos do § 1º do arti...
# 2  Apresentação do Projeto de Decreto Legislativo...
# 3  Devolva-se a proposição, por contrariar o disp...
# 4  Prazo de Recurso (5 sessões ordinárias a parti...
#
#   andamento_tramitacao_data            unique_id
# 0       2010-11-03 00:00:00 -3406100917335070313
# 1       2010-11-04 00:00:00  2575394321104112753
# 2       2010-08-04 00:00:00  7706943970270103526
# 3       2010-08-17 00:00:00  8182031166867923856
# 4       2010-08-17 00:00:00  5976673334173288414

# %%
tramitacoes_aborto['numlegislatura'] = np.nan

for idx, row in tramitacoes_aborto.iterrows():
    
    for periodo in legislaturas.keys():
        
        inicio = periodo[0]
        fim = periodo[1]
        
        if (row['andamento_tramitacao_data'] >= inicio) and (row['andamento_tramitacao_data'] <= fim):

            tramitacoes_aborto['numlegislatura'][idx] = legislaturas[periodo]
            pass
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tramitacoes_aborto.head()
# Out:
#    idProposicao nomeProposicao  \
# 0        484558  PDC 2840/2010
# 1        484558  PDC 2840/2010
# 2        484558  PDC 2840/2010
# 3        484558  PDC 2840/2010
# 4        484558  PDC 2840/2010
#
#                       andamento_tramitacao_descricao  \
# 0  Encerramento automático do Prazo de Recurso. N...
# 1  Devolvido ao Autor, nos termos do § 1º do arti...
# 2  Apresentação do Projeto de Decreto Legislativo...
# 3  Devolva-se a proposição, por contrariar o disp...
# 4  Prazo de Recurso (5 sessões ordinárias a parti...
#
#   andamento_tramitacao_data            unique_id  numlegislatura
# 0       2010-11-03 00:00:00 -3406100917335070313            53.0
# 1       2010-11-04 00:00:00  2575394321104112753            53.0
# 2       2010-08-04 00:00:00  7706943970270103526            53.0
# 3       2010-08-17 00:00:00  8182031166867923856            53.0
# 4       2010-08-17 00:00:00  5976673334173288414            53.0

# %% [markdown]
# ### Rede

# %% [markdown]
# #### Conjunto de nós

# %%
deps_atual = deputados[deputados['condicao'] == 'Titular'][['numlegislatura', 'nomeparlamentar']].drop_duplicates()
deps_atual.head()
# Out:
#    numlegislatura nomeparlamentar
# 0              55   SÉRGIO MORAES
# 1              55  SERGIO VIDIGAL
# 2              54       BOHN GASS
# 5              55   DANILO CABRAL
# 6              52     IRINY LOPES

# %%
deps_legs = deps_atual.groupby('numlegislatura')['nomeparlamentar'].apply(lambda x: x.tolist()).to_dict()
deps_legs
# Out:
# {52: ['IRINY LOPES',
#   'MARIA LUCIA',
#   'BONIFÁCIO DE ANDRADA',
#   'LUIZ ALBERTO',
#   'AGNELO QUEIROZ',
#   'REMI TRINTA',
#   'JOSÉ BORBA',
#   'EDNA MACEDO',
#   'ANSELMO',
#   'SANDRO MABEL',
#   'SANDRO MATOS',
#   'DRA. CLAIR',
#   'RAUL JUNGMANN',
#   'HOMERO BARRETO',
#   'ANTONIO JOAQUIM',
#   'JOSÉ DIRCEU',
#   'PAULO MAGALHÃES',
#   'MARCELINO FRAGA',
#   'LUIZ BASSUMA',
#   'JOÃO CAMPOS',
#   'PAUDERNEY AVELINO',
#   'ARMANDO MONTEIRO',
#   'BENJAMIN MARANHÃO',
#   'ZONTA',
#   'CLÓVIS FECURY',
#   'JULIO LOPES',
#   'ANTONIO CAMBRAIA',
#   'OLAVO CALHEIROS',
#   'AROLDE DE OLIVEIRA',
#   'RODRIGO MAIA',
#   'CELSO RUSSOMANNO',
#   'BENEDITO DE LIRA',
#   'LUIZ CARREIRA',
#   'CARLOS DUNGA',
#   'JOÃO MATOS',
#   'CARLITO MERSS',
#   'VICENTE CASCIONE',
#   'GILBERTO KASSAB',
#   'ONYX LORENZONI',
#   'DR. HELENO',
#   'JOÃO LYRA',
#   'LEODEGAR TISCOSKI',
#   'EDSON EZEQUIEL',
#   'MANINHA',
#   'DELFIM NETTO',
#   'NELSON MARQUEZELLI',
#   'DEVANIR RIBEIRO',
#   'NELSON PELLEGRINO',
#   'ÁTILA LINS',
#   'JOSÉ SANTANA DE VASCONCELLOS',
#   'JOÃO MENDES DE JESUS',
#   'BARBOSA NETO',
#   'JONIVAL LUCAS JUNIOR',
#   'SEBASTIÃO MADEIRA',
#   'NICIAS RIBEIRO',
#   'FÁTIMA BEZERRA',
#   'RUBENS OTONI',
#   'LEONARDO MATTOS',
#   'ODELMO LEÃO',
#   'GIVALDO CARIMBÃO',
#   'EDUARDO SEABRA',
#   'NEUTON LIMA',
#   'FERNANDO LOPES',
#   'MARCELO ORTIZ',
#   'VICENTINHO',
#   'JOSÉ IVO SARTORI',
#   'LEANDRO VILELA',
#   'JOSÉ EDUARDO CARDOZO',
#   'DAVI ALCOLUMBRE',
#   'DR. BENEDITO DIAS',
#   'PERPÉTUA ALMEIDA',
#   'DANILO DE CASTRO',
#   'ENÉAS',
#   'WILSON SANTOS',
#   'MILTON BARBOSA',
#   'ALOYSIO NUNES FERREIRA',
#   'DR. ROSINHA',
#   'JOSÉ JANENE',
#   'ZULAIÊ COBRA',
#   'RONIVON SANTIAGO',
#   'DURVAL ORLATO',
#   'PEDRO IRUJO',
#   'CÉSAR BANDEIRA',
#   'ODÍLIO BALBINOTTI',
#   'CARLOS MELLES',
#   'JOSÉ LINHARES',
#   'JUÍZA DENISE FROSSARD',
#   'EDSON DUARTE',
#   'PAULO BAUER',
#   'BABÁ',
#   'NARCISO MENDES',
#   'IBERÊ FERREIRA',
#   'DOMICIANO CABRAL',
#   'CORAUCI SOBRINHO',
#   'JORGE KHOURY',
#   'OSVALDO BIOLCHI',
#   'CORONEL ALVES',
#   'MOISÉS LIPNIK',
#   'LUIZA ERUNDINA',
#   'RENATO COZZOLINO',
#   'MÁRIO HERINGER',
#   'BOSCO COSTA',
#   'ALBERTO FRAGA',
#   'JOÃO HERRMANN NETO',
#   'ELISEU RESENDE',
#   'ROBERTO PESSOA',
#   'ALEXANDRE SANTOS',
#   'JOÃO ALMEIDA',
#   'JAIRO CARNEIRO',
#   'PROFESSORA RAQUEL TEIXEIRA',
#   'OLIVEIRA FILHO',
#   'ARACELY DE PAULA',
#   'GONZAGA PATRIOTA',
#   'JORGE BITTAR',
#   'ALICE PORTUGAL',
#   'CHICO DA PRINCESA',
#   'DR. RIBAMAR ALVES',
#   'LAURA CARNEIRO',
#   'LUIZ CARLOS HAULY',
#   'KELLY MORAES',
#   'ROGÉRIO TEÓFILO',
#   'JOSÉ MÚCIO MONTEIRO',
#   'ANTÔNIO CARLOS BIFFI',
#   'JOVINO CÂNDIDO',
#   'DR. EVILÁSIO',
#   'ARIOSTO HOLANDA',
#   'HELENO SILVA',
#   'WELLINGTON ROBERTO',
#   'PAULO AFONSO',
#   'HERMES PARCIANELLO',
#   'ROBSON TUMA',
#   'CABO JÚLIO',
#   'ARNALDO FARIA DE SÁ',
#   'JORGE BOEIRA',
#   'CONFÚCIO MOURA',
#   'MARCELLO SIQUEIRA',
#   'OSVALDO REIS',
#   'SÉRGIO CARVALHO',
#   'MIGUEL DE SOUZA',
#   'ZICO BRONZEADO',
#   'CELCITA PINHEIRO',
#   'BETINHO ROSADO',
#   'RONALDO CAIADO',
#   'JOÃO CORREIA',
#   'MOREIRA FRANCO',
#   'CARLOS SOUZA',
#   'ELISEU PADILHA',
#   'EDIR OLIVEIRA',
#   'EDMAR MOREIRA',
#   'NILTON CAPIXABA',
#   'JÚLIO CESAR',
#   'PAULO FEIJÓ',
#   'VIRGÍLIO GUIMARÃES',
#   'CARLOS SAMPAIO',
#   'ROMEU QUEIROZ',
#   'MAURO PASSOS',
#   'MARCELO CASTRO',
#   'JOSIAS GOMES',
#   'ARMANDO ABÍLIO',
#   'JOÃO BATISTA',
#   'MENDONÇA PRADO',
#   'VANDER LOUBET',
#   'WILSON SANTIAGO',
#   'LINDBERG FARIAS',
#   'PASTOR REINALDO',
#   'LUIZ PIAUHYLINO',
#   'JOAQUIM FRANCISCO',
#   'JOSÉ MENDONÇA BEZERRA',
#   'TELMA DE SOUZA',
#   'ROBERTO JEFFERSON',
#   'FERNANDO DE FABINHO',
#   'ROBERTO BALESTRA',
#   'EUNÍCIO OLIVEIRA',
#   'MIRO TEIXEIRA',
#   'RONALDO VASCONCELLOS',
#   'RAIMUNDO SANTOS',
#   'ASSIS MIGUEL DO COUTO',
#   'ROBÉRIO NUNES',
#   'DARCI COELHO',
#   'NEYDE APARECIDA',
#   'LUCIANO CASTRO',
#   'NILSON MOURÃO',
#   'DIMAS RAMALHO',
#   'BETO ALBUQUERQUE',
#   'CARLOS RODRIGUES',
#   'TAKAYAMA',
#   'MILTON MONTI',
#   'DELEY',
#   'WANDERVAL SANTOS',
#   'DR. PINOTTI',
#   'ROGÉRIO SILVA',
#   'MARCUS VICENTE',
#   'GERSON GABRIELLI',
#   'NELSON MEURER',
#   'FRANCISCO GARCIA',
#   'DR. HÉLIO',
#   'JACKSON BARRETO',
#   'SILAS CÂMARA',
#   'GUSTAVO FRUET',
#   'ANTONIO CARLOS BISCAIA',
#   'ANDERSON ADAUTO',
#   'MAURÍCIO QUINTELLA LESSA',
#   'MANATO',
#   'NELSON PROENÇA',
#   'VADÃO GOMES',
#   'JANDIRA FEGHALI',
#   'RAIMUNDO GOMES DE MATOS',
#   'RICARTE DE FREITAS',
#   'ADAUTO PEREIRA',
#   'VANDERLEI ASSIS',
#   'JOÃO GRANDÃO',
#   'FERNANDO CORUJA',
#   'HENRIQUE MEIRELLES',
#   'VITTORIO MEDIOLI',
#   'JOSÉ MILITÃO',
#   'JOSÉ CARLOS ELIAS',
#   'RAFAEL GUERRA',
#   'ROSE DE FREITAS',
#   'MAURÍCIO RABELO',
#   'MEDEIROS',
#   'OSMAR SERRAGLIO',
#   'ELIMAR MÁXIMO DAMASCENO',
#   'JOSÉ MENTOR',
#   'VIEIRA REIS',
#   'SAMEK',
#   'JOSÉ ROBERTO ARRUDA',
#   'TARCÍSIO ZIMMERMANN',
#   'MARIA HELENA',
#   'PROMOTOR AFONSO GIL',
#   'FRANCISCO TURRA',
#   'NEY LOPES',
#   'LUIS CARLOS HEINZE',
#   'MAURÍCIO RANDS',
#   'ANGELA GUADAGNIN',
#   'SÉRGIO MIRANDA',
#   'PASTOR FRANKEMBERGEN',
#   'BISMARCK MAIA',
#   'JÚNIOR BETÃO',
#   'PAULO PIMENTA',
#   'JOÃO ALFREDO',
#   'JOÃO FONTES',
#   'ANDRÉ DE PAULA',
#   'SEVERIANO ALVES',
#   'YEDA CRUSIUS',
#   'JÚLIO REDECKER',
#   'FRANCISCO DORNELLES',
#   'JAIME MARTINS',
#   'RICARDO IZAR',
#   'ORLANDO DESCONSI',
#   'GILBERTO NASCIMENTO',
#   'ALMIR MOURA',
#   'REGINALDO GERMANO',
#   'PAULO LIMA',
#   'MORAES SOUZA',
#   'RONALDO CEZAR COELHO',
#   'JUTAHY JUNIOR',
#   'LÉO ALCÂNTARA',
#   'PEDRO CHAVES',
#   'EDUARDO BARBOSA',
#   'CLEONÂNCIO FONSECA',
#   'RICARDO FIUZA',
#   'MUSSA DEMES',
#   'CIRO NOGUEIRA',
#   'GILMAR MACHADO',
#   'NEIVA MOREIRA',
#   'IRIS SIMÕES',
#   'ALEX CANZIANI',
#   'VIGNATTI',
#   'JOSÉ PRIANTE',
#   'JANETE CAPIBERIBE',
#   'MARIA DO ROSÁRIO',
#   'ROMMEL FEIJÓ',
#   'EDINHO BEZ',
#   'RICARDO BERZOINI',
#   'ZÉ GERARDO',
#   'LEONARDO VILELA',
#   'AUGUSTO NARDES',
#   'VIC PIRES FRANCO',
#   'PEDRO HENRY',
#   'JOSUÉ BENGTSON',
#   'SANDES JÚNIOR',
#   'LAEL VARELLA',
#   'VALDEMAR COSTA NETO',
#   'MARINHA RAUPP',
#   'COSTA FERREIRA',
#   'JOSIAS QUINTAL',
#   'SALVADOR ZIMBALDI',
#   'WAGNER LAGO',
#   'ELAINE COSTA',
#   'AROLDO CEDRAZ',
#   'FÉLIX MENDONÇA',
#   'ODAIR CUNHA',
#   'NARCIO RODRIGUES',
#   'RONALDO CUNHA LIMA',
#   'HUMBERTO MICHILES',
#   'JOÃO PAULO CUNHA',
#   'LEONARDO MONTEIRO',
#   'WELLINGTON FAGUNDES',
#   'PAULO GOUVÊA',
#   'OSVALDO COELHO',
#   'CARLOS SANTANA',
#   'LEONARDO PICCIANI',
#   'AMAURI GASQUES',
#   'ALDO REBELO',
#   'JORGE PINHEIRO',
#   'ROBERTO FREIRE',
#   'JOÃO CALDAS',
#   'ENIO BACCI',
#   'CEZAR SCHIRMER',
#   'JOÃO LEÃO',
#   'PINHEIRO LANDIM',
#   'SIMÃO SESSIM',
#   'PAULO BALTAZAR',
#   'KÁTIA ABREU',
#   'DR. FRANCISCO GONÇALVES',
#   'JORGE ALBERTO',
#   'ALCEU COLLARES',
#   'EDUARDO VALVERDE',
#   'LUCIANO LEITOA',
#   'PAULO RUBEM SANTIAGO',
#   'THELMA DE OLIVEIRA',
#   'JOÃO MAGALHÃES',
#   'IVO JOSÉ',
#   'LEÔNIDAS CRISTINO',
#   'DILCEU SPERAFICO',
#   'JEFFERSON CAMPOS',
#   'MARCOS ABRAMO',
#   'SANDRA ROSADO',
#   'EDUARDO SCIARRA',
#   'ASDRUBAL BENTES',
#   'MAX ROSENMANN',
#   'ORLANDO FANTAZZINI',
#   'NEUCIMAR FRAGA',
#   'ANÍBAL GOMES',
#   'ISAÍAS SILVESTRE',
#   'REGINALDO LOPES',
#   'WALTER PINHEIRO',
#   'TEREZINHA FERNANDES',
#   'CARLOS ABICALIL',
#   'POMPEO DE MATTOS',
#   'MÁRIO ASSAD JÚNIOR',
#   'ÁLVARO DIAS',
#   'MARIA DO CARMO LARA',
#   'PEDRO NOVAIS',
#   'CUSTÓDIO MATTOS',
#   'DANIEL ALMEIDA',
#   'JOÃO PIZZOLATTI',
#   'MIGUEL ARRAES',
#   'SARAIVA FELIPE',
#   'MICHEL TEMER',
#   'HENRIQUE EDUARDO ALVES',
#   'ROBERTO MAGALHÃES',
#   'MARCOS DE JESUS',
#   'ANDRÉ LUIZ',
#   'ANN PONTES',
#   'EDUARDO CUNHA',
#   'NILSON PINTO',
#   'FRANCISCO RODRIGUES',
#   'ILDEU ARAUJO',
#   'LINCOLN PORTELA',
#   'ALMERINDA DE CARVALHO',
#   'MARCELO GUIMARÃES FILHO',
#   'JOÃO PAULO GOMES DA SILVA',
#   'RONALDO DIMAS',
#   'ANTONIO CARLOS MAGALHÃES NETO',
#   'LUIZ SÉRGIO',
#   'TADEU FILIPPELLI',
#   'FLEURY',
#   'ANTONIO NOGUEIRA',
#   'ATHOS AVELINO',
#   'EDUARDO PAES',
#   'ANTONIO CARLOS PANNUNZIO',
#   'JOSÉ DIVINO',
#   'PASTOR AMARILDO',
#   'CEZAR SILVESTRI',
#   'ANDRÉ ZACHAROW',
#   'GASTÃO VIEIRA',
#   'GERVÁSIO OLIVEIRA',
#   'WALDEMIR MOKA',
#   'JOSÉ PIMENTEL',
#   'JOSÉ CARLOS ALELUIA',
#   'CARLOS EDUARDO CADOCA',
#   'B. SÁ',
#   'ZÉ LIMA',
#   'COLOMBO',
#   'VILMAR ROCHA',
#   'IVAN RANZOLIN',
#   'JOSÉ CARLOS ARAÚJO',
#   'OSMÂNIO PEREIRA',
#   'REINALDO BETÃO',
#   'ÉRICO RIBEIRO',
#   'LUCIANO ZICA',
#   'PAES LANDIM',
#   'WLADIMIR COSTA',
#   'ALCESTE ALMEIDA',
#   'NÉLIO DIAS',
#   'PATRUS ANANIAS',
#   'JÚLIO DELGADO',
#   'MARCELO TEIXEIRA',
#   'EDUARDO CAMPOS',
#   'GIACOBO',
#   'INOCÊNCIO OLIVEIRA',
#   'ARNON BEZERRA',
#   'CÉSAR MEDEIROS',
#   'SIGMARINGA SEIXAS',
#   'ROBERTO GOUVEIA',
#   'NILTON BAIANO',
#   'CLÁUDIO MAGRÃO',
#   'ROBERTO BRANT',
#   'PROFESSOR IRAPUAN TEIXEIRA',
#   'LUCI CHOINACKI',
#   'FÁBIO SOUTO',
#   'JOSÉ THOMAZ NONÔ',
#   'VICENTE ARRUDA',
#   'LUIZ BITTENCOURT',
#   'ARLINDO CHINAGLIA',
#   'AFFONSO CAMARGO',
#   'ARNALDO MADEIRA',
#   'HERCULANO ANGHINETTI',
#   'CLAUDIO CAJADO',
#   'ADELOR VIEIRA',
#   'ALEXANDRE CARDOSO',
#   'CARLOS WILLIAN',
#   'NICE LOBÃO',
#   'PAULO BERNARDO',
#   'FEU ROSA',
#   'PEDRO CORRÊA',
#   'COLBERT MARTINS',
#   'LUCIANA GENRO',
#   'PROFESSOR LUIZINHO',
#   'NELSON TRAD',
#   'ABELARDO LUPION',
#   'MOACIR MICHELETTO',
#   'JOSÉ CARLOS MARTINEZ',
#   'JOÃO MAGNO',
#   'PHILEMON RODRIGUES',
#   'ZENALDO COUTINHO',
#   'LUPÉRCIO RAMOS',
#   'VANESSA GRAZZIOTIN',
#   'CARLOS ALBERTO LERÉIA',
#   'ZÉ GERALDO',
#   'ANTONIO CRUZ',
#   'LUIZ CARLOS SANTOS',
#   'SUELY CAMPOS',
#   'PAULO DELGADO',
#   'JOÃO CASTELO',
#   'JULIO SEMEGHINI',
#   'RENILDO CALHEIROS',
#   'JOVAIR ARANTES',
#   'MORONI TORGAN',
#   'GERVÁSIO SILVA',
#   'JOSÉ OTÁVIO GERMANO',
#   'DR. RODOLFO PEREIRA',
#   'SEVERINO CAVALCANTI',
#   'IVAN VALENTE',
#   'FRANCISCA TRINDADE',
#   'ALMEIDA DE JESUS',
#   'GUILHERME MENEZES',
#   'TATICO',
#   'MAURO LOPES',
#   'SARNEY FILHO',
#   'CHICO ALENCAR',
#   'EDUARDO GOMES',
#   'JOSÉ CHAVES',
#   'GERALDO RESENDE',
#   'JADER BARBALHO',
#   'LOBBE NETO',
#   'RENATO CASAGRANDE',
#   'GERALDO THADEU',
#   'HENRIQUE FONTANA',
#   'CORIOLANO SALES',
#   'MÁRCIO REINALDO MOREIRA',
#   'MURILO ZAUITH',
#   'PEDRO FERNANDES',
#   'PASTOR PEDRO RIBEIRO',
#   'HENRIQUE AFONSO',
#   'WALTER FELDMAN',
#   'SILAS BRASILEIRO',
#   'LÚCIA BRAGA',
#   'DARCÍSIO PERONDI',
#   'PAULO MARINHO',
#   'IARA BERNARDI',
#   'ANTONIO CARLOS MENDES THAME',
#   'MENDES RIBEIRO FILHO',
#   'NELSON BORNIER',
#   'ADÃO PRETTO',
#   'JOSÉ ROCHA',
#   'JAIR BOLSONARO',
#   'HÉLIO ESTEVES',
#   'ÁTILA LIRA',
#   'ZELINDA NOVAES',
#   'ZEZÉU RIBEIRO',
#   'LUIZ COUTO',
#   'FERNANDO DINIZ',
#   'MÁRIO NEGROMONTE',
#   'FERNANDO FERRO',
#   'AGNALDO MUNIZ',
#   'ZEQUINHA MARINHO',
#   'INÁCIO ARRUDA',
#   'HELENILDO RIBEIRO',
#   'PAULO ROCHA',
#   'PASTOR FRANCISCO OLÍMPIO',
#   'JOSÉ CARLOS MACHADO',
#   'ALBERTO GOLDMAN',
#   'ANIVALDO VALE',
#   'GEDDEL VIEIRA LIMA',
#   'JAMIL MURAD',
#   'BERNARDO ARISTON',
#   'FERNANDO GABEIRA',
#   'ENIVALDO RIBEIRO',
#   'RICARDO BARROS',
#   'ARY VANAZZI',
#   'LUIZ EDUARDO GREENHALGH'],
#  53: ['ZENALDO COUTINHO',
#   'JOÃO MATOS',
#   'JÚLIO CESAR',
#   'ABELARDO LUPION',
#   'NELSON PROENÇA',
#   'HUGO LEAL',
#   'CIRO NOGUEIRA',
#   'ANTONIO JOSÉ MEDEIROS',
#   'JOSÉ ANÍBAL',
#   'MARINA MAGGESSI',
#   'CELSO RUSSOMANNO',
#   'PROFESSOR RUY PAULETTI',
#   'RONALDO CUNHA LIMA',
#   'VADÃO GOMES',
#   'RICARDO IZAR',
#   'MÁRIO HERINGER',
#   'FERNANDO DINIZ',
#   'CHICO ALENCAR',
#   'ROGÉRIO MARINHO',
#   'LUCIANO CASTRO',
#   'PAULO BORNHAUSEN',
#   'CARLOS SOUZA',
#   'REINALDO NOGUEIRA',
#   'PAULO PIMENTA',
#   'GEDDEL VIEIRA LIMA',
#   'ARMANDO ABÍLIO',
#   'MIRO TEIXEIRA',
#   'WOLNEY QUEIROZ',
#   'PAES LANDIM',
#   'WELLINGTON FAGUNDES',
#   'VANESSA GRAZZIOTIN',
#   'JOSÉ CARLOS MACHADO',
#   'EDUARDO VALVERDE',
#   'CIRO GOMES',
#   'ANGELA PORTELA',
#   'ARMANDO MONTEIRO',
#   'SÉRGIO MORAES',
#   'MARCIO JUNQUEIRA',
#   'PAULO RENATO SOUZA',
#   'ELCIONE BARBALHO',
#   'SEBASTIÃO MADEIRA',
#   'RICARDO BARROS',
#   'JOÃO CAMPOS',
#   'RENATO MOLLING',
#   'ENÉAS',
#   'ADEMIR CAMILO',
#   'FELIPE MAIA',
#   'EDSON SANTOS',
#   'JOSÉ PIMENTEL',
#   'GILMAR MACHADO',
#   'BILAC PINTO',
#   'ALBANO FRANCO',
#   'EUGÊNIO RABELO',
#   'FÁTIMA BEZERRA',
#   'ADÃO PRETTO',
#   'EDSON APARECIDO',
#   'ANÍBAL GOMES',
#   'ÁTILA LIRA',
#   'EDUARDO AMORIM',
#   'DR. PINOTTI',
#   'DAVI ALCOLUMBRE',
#   'ÁTILA LINS',
#   'ANTONIO BULHÕES',
#   'GONZAGA PATRIOTA',
#   'EUDES XAVIER',
#   'HOMERO PEREIRA',
#   'ANTONIO CRUZ',
#   'RODRIGO MAIA',
#   'JOSÉ CARLOS ALELUIA',
#   'ROSE DE FREITAS',
#   'MAURO LOPES',
#   'ANTÔNIO ANDRADE',
#   'WLADIMIR COSTA',
#   'NELSON PELLEGRINO',
#   'PEDRO WILSON',
#   'ARNALDO FARIA DE SÁ',
#   'SOLANGE ALMEIDA',
#   'RIBAMAR ALVES',
#   'WALTER FELDMAN',
#   'BONIFÁCIO DE ANDRADA',
#   'BETO FARO',
#   'CELSO MALDANER',
#   'MARCONDES GADELHA',
#   'LUIZ PAULO VELLOZO LUCAS',
#   'PAULO RUBEM SANTIAGO',
#   'DIMAS RAMALHO',
#   'PAULO TEIXEIRA',
#   'LEONARDO PICCIANI',
#   'ARNALDO JARDIM',
#   'ALEXANDRE SILVEIRA',
#   'PAULO ROCHA',
#   'ALEX CANZIANI',
#   'RAIMUNDO GOMES DE MATOS',
#   'MANOEL JUNIOR',
#   'IRAN BARBOSA',
#   'ANGELA AMIN',
#   'PAULO MAGALHÃES',
#   'GUILHERME MENEZES',
#   'GIOVANNI QUEIROZ',
#   'CUSTÓDIO MATTOS',
#   'DUARTE NOGUEIRA',
#   'TARCÍSIO ZIMMERMANN',
#   'DR. UBIALI',
#   'LUIZA ERUNDINA',
#   'JULIÃO AMIN',
#   'MARIA DO CARMO LARA',
#   'FILIPE PEREIRA',
#   'MAGELA',
#   'RATINHO JUNIOR',
#   'AUGUSTO CARVALHO',
#   'MÁRCIO FRANÇA',
#   'ANTONIO CARLOS MENDES THAME',
#   'DAGOBERTO',
#   'BENEDITO DE LIRA',
#   'ANDRE VARGAS',
#   'NELSON MEURER',
#   'JERÔNIMO REIS',
#   'JOSÉ CARLOS ARAÚJO',
#   'LÚCIO VALE',
#   'GERALDO PUDIM',
#   'ALICE PORTUGAL',
#   'FRANCISCO RODRIGUES',
#   'POMPEO DE MATTOS',
#   'MAURÍCIO RANDS',
#   'DR. ROSINHA',
#   'MARCOS MONTES',
#   'ODÍLIO BALBINOTTI',
#   'RAUL JUNGMANN',
#   'AFONSO HAMM',
#   'ALBERTO FRAGA',
#   'ARNON BEZERRA',
#   'CARLOS SAMPAIO',
#   'ALFREDO KAEFER',
#   'SERGIO PETECÃO',
#   'GERÔNIMO DA ADEFAL',
#   'ALDO REBELO',
#   'TATICO',
#   'JANETE ROCHA PIETÁ',
#   'MARCELO TEIXEIRA',
#   'LEANDRO SAMPAIO',
#   'IRINY LOPES',
#   'MARCOS MEDRADO',
#   'SANDRO MABEL',
#   'MARCELO MELO',
#   'JÚLIO DELGADO',
#   'DARCÍSIO PERONDI',
#   'HENRIQUE EDUARDO ALVES',
#   'PAULO HENRIQUE LUSTOSA',
#   'DELEY',
#   'CARLOS MELLES',
#   'JANETE CAPIBERIBE',
#   'OLAVO CALHEIROS',
#   'NEUCIMAR FRAGA',
#   'JOSÉ ROCHA',
#   'VIC PIRES FRANCO',
#   'JILMAR TATTO',
#   'GUILHERME CAMPOS',
#   'PEDRO NOVAIS',
#   'WILLIAM WOO',
#   'MARINHA RAUPP',
#   'CARLOS ALBERTO LERÉIA',
#   'GERALDO RESENDE',
#   'EVANDRO MILHOMEN',
#   'JOÃO OLIVEIRA',
#   'MARCO MAIA',
#   'TONHA MAGALHÃES',
#   'ZÉ GERALDO',
#   'BETO MANSUR',
#   'ARLINDO CHINAGLIA',
#   'ONYX LORENZONI',
#   'GORETE PEREIRA',
#   'SARAIVA FELIPE',
#   'MAURO MARIANI',
#   'PAULO ROBERTO PEREIRA',
#   'DEVANIR RIBEIRO',
#   'ÍRIS DE ARAÚJO',
#   'RAFAEL GUERRA',
#   'VELOSO',
#   'ROBERTO MAGALHÃES',
#   'LINDOMAR GARÇON',
#   'SILVIO LOPES',
#   'LUIZ CARLOS BUSATO',
#   'RICARDO BERZOINI',
#   'ROBERTO BALESTRA',
#   'DAMIÃO FELICIANO',
#   'JURANDY LOUREIRO',
#   'JOÃO ALMEIDA',
#   'LUIZ BASSUMA',
#   'ZEZÉU RIBEIRO',
#   'JOSÉ EDUARDO CARDOZO',
#   'JÔ MORAES',
#   'LAEL VARELLA',
#   'CARLOS ZARATTINI',
#   'ANGELO VANHONI',
#   'BETO ALBUQUERQUE',
#   'SARNEY FILHO',
#   'SEVERIANO ALVES',
#   'ARNALDO VIANNA',
#   'ROGERIO LISBOA',
#   'VALADARES FILHO',
#   'CAMILO COLA',
#   'WILSON BRAGA',
#   'NEILTON MULIM',
#   'FERNANDO DE FABINHO',
#   'REGIS DE OLIVEIRA',
#   'LEANDRO VILELA',
#   'CRISTIANO MATHEUS',
#   'JOSÉ MENDONÇA BEZERRA',
#   'GIACOBO',
#   'TAKAYAMA',
#   'ANTÔNIO CARLOS BIFFI',
#   'CLÓVIS FECURY',
#   'PAULO PIAU',
#   'SÉRGIO BRITO',
#   'CARLOS BEZERRA',
#   'VANDERLEI MACRIS',
#   'LUIZ ALBERTO',
#   'JOÃO BITTAR',
#   'JORGE BITTAR',
#   'ROBERTO SANTIAGO',
#   'JAIR BOLSONARO',
#   'CÂNDIDO VACCAREZZA',
#   'EDUARDO CUNHA',
#   'VIGNATTI',
#   'ALBERTO SILVA',
#   'SANDES JÚNIOR',
#   'SABINO CASTELO BRANCO',
#   'JOVAIR ARANTES',
#   'FRANK AGUIAR',
#   'PEDRO EUGÊNIO',
#   'VICENTINHO',
#   'SÉRGIO BARRADAS CARNEIRO',
#   'FÁBIO RAMALHO',
#   'ASSIS DO COUTO',
#   'RUBENS OTONI',
#   'EDUARDO BARBOSA',
#   'GUSTAVO FRUET',
#   'ALEXANDRE SANTOS',
#   'FERNANDO LOPES',
#   'JACKSON BARRETO',
#   'BERNARDO ARISTON',
#   'LUIS CARLOS HEINZE',
#   'OSMAR SERRAGLIO',
#   'PEPE VARGAS',
#   'CARLOS WILSON',
#   'EDIO LOPES',
#   'RITA CAMATA',
#   'JORGE TADEU MUDALEN',
#   'MÁRIO DE OLIVEIRA',
#   'FÁBIO FARIA',
#   'MANOEL SALVIANO',
#   'FÉLIX MENDONÇA',
#   'NÉLIO DIAS',
#   'DJALMA BERGER',
#   'WELLINGTON ROBERTO',
#   'MÁRCIO REINALDO MOREIRA',
#   'ZÉ GERARDO',
#   'EMANUEL FERNANDES',
#   'NILSON MOURÃO',
#   'GERSON PERES',
#   'PERPÉTUA ALMEIDA',
#   'HENRIQUE AFONSO',
#   'MARCELO CASTRO',
#   'CIRO PEDROSA',
#   'HENRIQUE FONTANA',
#   'LUCENIRA PIMENTEL',
#   'MARIA LÚCIA CARDOSO',
#   'LUIZ FERNANDO FARIA',
#   'VICENTINHO ALVES',
#   'RODRIGO ROLLEMBERG',
#   'SIMÃO SESSIM',
#   'ELISEU PADILHA',
#   'MOREIRA MENDES',
#   'WANDENKOLK GONÇALVES',
#   'THELMA DE OLIVEIRA',
#   'LUIZ SÉRGIO',
#   'OSVALDO REIS',
#   'DALVA FIGUEIREDO',
#   'REINHOLD STEPHANES',
#   'ANTONIO CARLOS MAGALHÃES NETO',
#   'VALDIR COLATTO',
#   'SANDRA ROSADO',
#   'VALDEMAR COSTA NETO',
#   'GEORGE HILTON',
#   'MARIA HELENA',
#   'GLADSON CAMELI',
#   'FERNANDO CHUCRE',
#   'CEZAR SILVESTRI',
#   'JURANDIL JUAREZ',
#   'NELSON GOETTEN',
#   "CHICO D'ANGELO",
#   'JORGE KHOURY',
#   'VITOR PENIDO',
#   'MOACIR MICHELETTO',
#   'CARLOS ABICALIL',
#   'LUIZ CARLOS HAULY',
#   'DANIEL ALMEIDA',
#   'ZEQUINHA MARINHO',
#   'MENDES RIBEIRO FILHO',
#   'SILVINHO PECCIOLI',
#   'LOBBE NETO',
#   'PASTOR MANOEL FERREIRA',
#   'FRANCISCO TENORIO',
#   'CARLOS SANTANA',
#   'BRUNO RODRIGUES',
#   'EDINHO BEZ',
#   'DR. ADILSON SOARES',
#   'BEL MESQUITA',
#   'JOSÉ CHAVES',
#   'JOSÉ GUIMARÃES',
#   'ENIO BACCI',
#   'PAULO ABI-ACKEL',
#   'EDUARDO DA FONTE',
#   'NILSON PINTO',
#   'LAUREZ MOREIRA',
#   'CLAUDIO CAJADO',
#   'OSMAR JÚNIOR',
#   'SUELY',
#   'ANDREIA ZITO',
#   'CLODOVIL HERNANDES',
#   'RÔMULO GOUVEIA',
#   'FLAVIANO MELO',
#   'ANTONIO CARLOS PANNUNZIO',
#   'LEO ALCÂNTARA',
#   'RODRIGO ROCHA LOURES',
#   'EDMAR MOREIRA',
#   'VANDER LOUBET',
#   'ERNANDES AMORIM',
#   'CARLITO MERSS',
#   'EDGAR MOURY',
#   'NELSON BORNIER',
#   'BARBOSA NETO',
#   'CARLOS BRANDÃO',
#   'JOÃO PIZZOLATTI',
#   'LEONARDO QUINTÃO',
#   'ANTÔNIO ROBERTO',
#   'NATAN DONADON',
#   'LELO COIMBRA',
#   'MARCELO ORTIZ',
#   'JOÃO PAULO CUNHA',
#   'FELIPE BORNIER',
#   'NAZARENO FONTELES',
#   'PINTO ITAMARATY',
#   'SILVIO TORRES',
#   'PROFESSORA RAQUEL TEIXEIRA',
#   'MARCELO GUIMARÃES FILHO',
#   'RENATO AMARY',
#   'VALTENIR PEREIRA',
#   "MANUELA D'ÁVILA",
#   'EDSON DUARTE',
#   'GERALDO SIMÕES',
#   'FERNANDO COELHO FILHO',
#   'LUCIANA GENRO',
#   'JOSÉ OTÁVIO GERMANO',
#   'ODAIR CUNHA',
#   'FRANCISCO ROSSI',
#   'FLÁVIO BEZERRA',
#   'SILAS CÂMARA',
#   'AFFONSO CAMARGO',
#   'PEDRO HENRY',
#   'JOAQUIM BELTRÃO',
#   'MARCOS ANTONIO',
#   'ANDRÉ DE PAULA',
#   'CARLOS EDUARDO CADOCA',
#   'ARACELY DE PAULA',
#   'WALTER IHOSHI',
#   'GERALDO THADEU',
#   'LÉO VIVAS',
#   'ZONTA',
#   'ASDRUBAL BENTES',
#   'NELSON TRAD',
#   'VITAL DO RÊGO FILHO',
#   'ANA ARRAES',
#   'MICHEL TEMER',
#   'EDMILSON VALENTIM',
#   'LUIZ CARREIRA',
#   'DOMINGOS DUTRA',
#   'NELSON MARQUEZELLI',
#   'PEDRO CHAVES',
#   'JADER BARBALHO',
#   'COLBERT MARTINS',
#   'ANTONIO PALOCCI',
#   'JUSMARI OLIVEIRA',
#   'IVAN VALENTE',
#   'DÉCIO LIMA',
#   'FERNANDO MELO',
#   'VICENTE ARRUDA',
#   'FERNANDO FERRO',
#   'CHICO DA PRINCESA',
#   'MIGUEL CORRÊA',
#   'PAULO MALUF',
#   'ALINE CORRÊA',
#   'MARIA DO ROSÁRIO',
#   'ROBERTO ROCHA',
#   'ROBERTO BRITTO',
#   'LEONARDO MONTEIRO',
#   'PAULO PEREIRA DA SILVA',
#   'FERNANDO GABEIRA',
#   'CIDA DIOGO',
#   'CLEBER VERDE',
#   'FÁBIO SOUTO',
#   'LUIZ BITTENCOURT',
#   'EDUARDO SCIARRA',
#   'EFRAIM FILHO',
#   'MILTON MONTI',
#   'ELIENE LIMA',
#   'JOÃO LEÃO',
#   'HUMBERTO SOUTO',
#   'BRIZOLA NETO',
#   'DR. NECHAR',
#   'JOSÉ MÚCIO MONTEIRO',
#   'AROLDE DE OLIVEIRA',
#   'VIEIRA DA CUNHA',
#   'RONALDO CAIADO',
#   'JAIME MARTINS',
#   'FRANCISCO PRACIANO',
#   'MUSSA DEMES',
#   'LÁZARO BOTELHO',
#   'WILSON SANTIAGO',
#   'RENILDO CALHEIROS',
#   'LUIZ CARLOS SETIM',
#   'VILSON COVATTI',
#   'ARNALDO MADEIRA',
#   'JOSÉ FERNANDO APARECIDO DE OLIVEIRA',
#   'LEONARDO VILELA',
#   'JOSÉ PAULO TÓFFANO',
#   'WALDIR MARANHÃO',
#   'MARCELO ITAGIBA',
#   'INDIO DA COSTA',
#   'NARCIO RODRIGUES',
#   'LINCOLN PORTELA',
#   'GASTÃO VIEIRA',
#   'TADEU FILIPPELLI',
#   'PROFESSOR SETIMO',
#   'MÁRIO NEGROMONTE',
#   'JULIO SEMEGHINI',
#   'MAURO NAZIF',
#   'EDSON EZEQUIEL',
#   'REBECCA GARCIA',
#   'WALTER PINHEIRO',
#   'VINICIUS CARVALHO',
#   'SOLANGE AMARAL',
#   'MARCELO SERAFIM',
#   'OSMAR TERRA',
#   'CARLOS WILLIAN',
#   'HERMES PARCIANELLO',
#   'JOSÉ SANTANA DE VASCONCELLOS',
#   'JOFRAN FREJAT',
#   'MAX ROSENMANN',
#   'OTAVIO LEITE',
#   'GIVALDO CARIMBÃO',
#   'URZENI ROCHA',
#   'PEDRO FERNANDES',
#   'JOÃO MAIA',
#   'LÍDICE DA MATA',
#   'MAURÍCIO TRINDADE',
#   'JUTAHY JUNIOR',
#   'MOISES AVELINO',
#   'NICE LOBÃO',
#   'DILCEU SPERAFICO',
#   'AELTON FREITAS',
#   'CHICO LOPES',
#   'JOSÉ LINHARES',
#   'ALEXANDRE CARDOSO',
#   'JOÃO DADO',
#   'WALDIR NEVES',
#   'GERMANO BONOW',
#   'NILMAR RUIZ',
#   'DR. TALMIR',
#   'SANDRO MATOS',
#   'MANATO',
#   'CARLOS ALBERTO CANUTO',
#   'RAUL HENRY',
#   'EUNÍCIO OLIVEIRA',
#   'LIRA MAIA',
#   'RODRIGO DE CASTRO',
#   'ANSELMO DE JESUS',
#   'ILDERLEI CORDEIRO',
#   'IBSEN PINHEIRO',
#   'MAURÍCIO QUINTELLA LESSA',
#   'JÚLIO REDECKER',
#   'WALDEMIR MOKA',
#   'ALCENI GUERRA',
#   'ELISMAR PRADO',
#   'JOSÉ MENTOR',
#   'JUVENIL',
#   'INOCÊNCIO OLIVEIRA',
#   'BRUNO ARAÚJO',
#   'JOÃO MAGALHÃES',
#   'DAVI ALVES SILVA JÚNIOR',
#   'LUIZ COUTO',
#   'EDUARDO GOMES',
#   'VIRGÍLIO GUIMARÃES',
#   'ABELARDO CAMARINHA',
#   'JOSÉ AIRTON CIRILO',
#   'REGINALDO LOPES',
#   'MAURO BENEVIDES',
#   'ARIOSTO HOLANDA',
#   'JOSÉ GENOÍNO',
#   'SUELI VIDIGAL',
#   'FLÁVIO DINO',
#   'MENDONÇA PRADO',
#   'SEBASTIÃO BALA ROCHA',
#   'CASSIO TANIGUCHI',
#   'LAERTE BESSA',
#   'FÁTIMA PELAES',
#   'MIGUEL MARTINI',
#   'NEUDO CAMPOS',
#   'GERVÁSIO SILVA',
#   'JOÃO CARLOS BACELAR',
#   'FERNANDO CORUJA',
#   'RODOVALHO',
#   'RICARDO TRIPOLI'],
#  54: ['BOHN GASS',
#   'FLÁVIA MORAIS',
#   'ANDREIA ZITO',
#   'MARLLOS SAMPAIO',
#   'OZIEL OLIVEIRA',
#   'BETINHO ROSADO',
#   'NELSON MARQUEZELLI',
#   'HERMES PARCIANELLO',
#   'GONZAGA PATRIOTA',
#   'MARCON',
#   'RAIMUNDÃO',
#   'PAES LANDIM',
#   'ANDRÉ FIGUEIREDO',
#   'ÍRIS DE ARAÚJO',
#   'ROBERTO BRITTO',
#   'JUNJI ABE',
#   'ANTONIO BULHÕES',
#   'DELEGADO PROTÓGENES',
#   'CHICO LOPES',
#   'LAURIETE',
#   'ZECA DIRCEU',
#   'BETO ALBUQUERQUE',
#   'FÁBIO FARIA',
#   'MANOEL JUNIOR',
#   'CARLOS MAGNO',
#   'RONALDO BENEDET',
#   'ROGÉRIO CARVALHO',
#   'WELLINGTON FAGUNDES',
#   'GABRIEL CHALITA',
#   'PAULO TADEU',
#   'ARNON BEZERRA',
#   'IRACEMA PORTELLA',
#   'JÚLIO CESAR',
#   'GIACOBO',
#   'PINTO ITAMARATY',
#   'VALDEMAR COSTA NETO',
#   'EDUARDO CUNHA',
#   'RAIMUNDO GOMES DE MATOS',
#   'ALDO REBELO',
#   'ALICE PORTUGAL',
#   'GERALDO RESENDE',
#   'ALEXANDRE LEITE',
#   'JEFFERSON CAMPOS',
#   'RATINHO JUNIOR',
#   'ALINE CORRÊA',
#   'DAMIÃO FELICIANO',
#   'OSMAR JÚNIOR',
#   'DR. PAULO CÉSAR',
#   'LEOPOLDO MEYER',
#   'SARAIVA FELIPE',
#   'JESUS RODRIGUES',
#   'ABELARDO CAMARINHA',
#   'JOSE STÉDILE',
#   'DANILO FORTE',
#   'NEWTON CARDOSO',
#   'HUGO MOTTA',
#   'JÂNIO NATAL',
#   'VILSON COVATTI',
#   'ROSINHA DA ADEFAL',
#   'LUCI CHOINACKI',
#   'JOÃO LYRA',
#   'SALVADOR ZIMBALDI',
#   'BENJAMIN MARANHÃO',
#   'ABELARDO LUPION',
#   'PAULO BORNHAUSEN',
#   'FRANCISCO PRACIANO',
#   'CLAUDIO CAJADO',
#   'SANDRA ROSADO',
#   'JOSIAS GOMES',
#   'VIEIRA DA CUNHA',
#   'VINICIUS GURGEL',
#   'HENRIQUE FONTANA',
#   'SANDES JÚNIOR',
#   'ANDRÉ ZACHAROW',
#   'WASHINGTON REIS',
#   'AMAURI TEIXEIRA',
#   'MILTON MONTI',
#   'CELIA ROCHA',
#   'JOAQUIM BELTRÃO',
#   'NILSON PINTO',
#   'GIROTO',
#   'MANDETTA',
#   'GERALDO SIMÕES',
#   'EDUARDO BARBOSA',
#   'BENEDITA DA SILVA',
#   'MIRIQUINHO BATISTA',
#   'CHICO ALENCAR',
#   'MOACIR MICHELETTO',
#   'SILVIO COSTA',
#   'JOÃO CAMPOS',
#   'AROLDE DE OLIVEIRA',
#   'RENATO MOLLING',
#   'WILSON FILHO',
#   'KEIKO OTA',
#   'EDUARDO SCIARRA',
#   'THIAGO PEIXOTO',
#   'JOÃO RODRIGUES',
#   'CARLOS SOUZA',
#   'JOSUÉ BENGTSON',
#   'LEONARDO MONTEIRO',
#   'RENAN FILHO',
#   'SIBÁ MACHADO',
#   'BRUNO ARAÚJO',
#   'JÚLIO DELGADO',
#   'ERIVELTON SANTANA',
#   'NARCIO RODRIGUES',
#   'JORGE BITTAR',
#   'ANTÔNIO ROBERTO',
#   'NILTON CAPIXABA',
#   'PAUDERNEY AVELINO',
#   'ALBERTO FILHO',
#   'GIVALDO CARIMBÃO',
#   'FERNANDO FRANCISCHINI',
#   'MANOEL SALVIANO',
#   'LUCIANO MOREIRA',
#   'PENNA',
#   'ARMANDO VERGÍLIO',
#   'MISSIONÁRIO JOSÉ OLIMPIO',
#   'PAULO WAGNER',
#   'EDSON APARECIDO',
#   'EDIO LOPES',
#   'FERNANDO COELHO FILHO',
#   'PADRE TON',
#   'GABRIEL GUIMARÃES',
#   'REGUFFE',
#   'DÉCIO LIMA',
#   'CESAR COLNAGO',
#   'DR. ROSINHA',
#   'NEILTON MULIM',
#   'BRUNA FURLAN',
#   'DANIEL ALMEIDA',
#   'ANTONIO BRITO',
#   'WALDIR MARANHÃO',
#   'EVANDRO MILHOMEN',
#   'RONALDO CAIADO',
#   'ANTÔNIA LÚCIA',
#   'RUBENS OTONI',
#   'RAUL HENRY',
#   'PAULO FOLETTO',
#   'ANTÔNIO ANDRADE',
#   'WALTER TOSTA',
#   'NILSON LEITÃO',
#   'MIRO TEIXEIRA',
#   'AGUINALDO RIBEIRO',
#   'ARTHUR OLIVEIRA MAIA',
#   'ANTONIO CARLOS MAGALHÃES NETO',
#   'MARINHA RAUPP',
#   'JHONATAN DE JESUS',
#   'ESPERIDIÃO AMIN',
#   'CARLOS ALBERTO LERÉIA',
#   'RODRIGO MAIA',
#   'IRINY LOPES',
#   'INOCÊNCIO OLIVEIRA',
#   'MAURO MARIANI',
#   'CLEBER VERDE',
#   'TONINHO PINHEIRO',
#   'ANA ARRAES',
#   'PEDRO EUGÊNIO',
#   'ASSIS CARVALHO',
#   'MAURO BENEVIDES',
#   'EDUARDO DA FONTE',
#   'CHICO DAS VERDURAS',
#   'JÚLIO CAMPOS',
#   'JULIO LOPES',
#   'VAZ DE LIMA',
#   'LUIZA ERUNDINA',
#   'RONALDO FONSECA',
#   'JOSÉ HUMBERTO',
#   'DR. ALUIZIO',
#   'LUIZ CARLOS BUSATO',
#   'WOLNEY QUEIROZ',
#   'ASSIS MELO',
#   'LUIZ ARGÔLO',
#   'OTONIEL LIMA',
#   'AUREO',
#   'NILDA GONDIM',
#   'MARCO MAIA',
#   'ALEXANDRE SILVEIRA',
#   'MENDES RIBEIRO FILHO',
#   'SÉRGIO BRITO',
#   'JAIME MARTINS',
#   'ROMÁRIO',
#   'CARLOS EDUARDO CADOCA',
#   'PEDRO HENRY',
#   'LINCOLN PORTELA',
#   'ROBERTO DE LUCENA',
#   'EMANUEL FERNANDES',
#   'CARLOS ZARATTINI',
#   'ROMERO RODRIGUES',
#   'LAUREZ MOREIRA',
#   'RODRIGO DE CASTRO',
#   'EDUARDO AZEREDO',
#   'MARCOS MEDRADO',
#   'WELITON PRADO',
#   'GENECIAS NORONHA',
#   'PAULO FREIRE',
#   'RICARDO BERZOINI',
#   'ENIO BACCI',
#   'LUCIANA SANTOS',
#   'GEORGE HILTON',
#   'LUIZ ALBERTO',
#   'OTAVIO LEITE',
#   'MÁRIO NEGROMONTE',
#   'JORGE TADEU MUDALEN',
#   'DIMAS RAMALHO',
#   'DILCEU SPERAFICO',
#   'CARLOS BEZERRA',
#   'VILMAR ROCHA',
#   'RUBENS BUENO',
#   'MIGUEL CORRÊA',
#   'ALCEU MOREIRA',
#   'ARIOSTO HOLANDA',
#   'VALMIR ASSUNÇÃO',
#   'DR. GRILO',
#   'DARCÍSIO PERONDI',
#   'BERINHO BANTIM',
#   'FRANCISCO FLORIANO',
#   'ANDRE MOURA',
#   'ANTONIO CARLOS MENDES THAME',
#   'ANÍBAL GOMES',
#   'PAULO MAGALHÃES',
#   'JOSÉ MENTOR',
#   'LUIZ FERNANDO FARIA',
#   'GLAUBER BRAGA',
#   'ALEX CANZIANI',
#   'JOSÉ GUIMARÃES',
#   'BIFFI',
#   'ZEZÉU RIBEIRO',
#   'LILIAM SÁ',
#   'ASDRUBAL BENTES',
#   'ELCIONE BARBALHO',
#   'MARCOS MONTES',
#   'ARNALDO FARIA DE SÁ',
#   'BILAC PINTO',
#   'ALFREDO SIRKIS',
#   'IRAJÁ ABREU',
#   'FÁTIMA PELAES',
#   'JOÃO PAULO LIMA',
#   'ODAIR CUNHA',
#   'NELSON MARCHEZAN JUNIOR',
#   'GIOVANI CHERINI',
#   'DOMINGOS DUTRA',
#   'JOÃO CARLOS BACELAR',
#   'NEWTON LIMA',
#   'TAUMATURGO LIMA',
#   'ANDRE VARGAS',
#   'ELIENE LIMA',
#   'JOSÉ PRIANTE',
#   'ADEMIR CAMILO',
#   'JAQUELINE RORIZ',
#   'FILIPE PEREIRA',
#   'JILMAR TATTO',
#   'PEPE VARGAS',
#   'STEPAN NERCESSIAN',
#   'JOSÉ NUNES',
#   'GORETE PEREIRA',
#   'AELTON FREITAS',
#   'RODRIGO BETHLEM',
#   'RICARDO IZAR',
#   'FERNANDO TORRES',
#   'DALVA FIGUEIREDO',
#   'OSMAR SERRAGLIO',
#   'JOÃO MAGALHÃES',
#   'ROBERTO SANTIAGO',
#   'PAULO TEIXEIRA',
#   'RIBAMAR ALVES',
#   'VITOR PAULO',
#   'CELSO MALDANER',
#   'ZÉ GERALDO',
#   "MANUELA D'ÁVILA",
#   'FELIPE MAIA',
#   'PEDRO PAULO',
#   'FÁTIMA BEZERRA',
#   'LUCIANO CASTRO',
#   'RONALDO ZULKE',
#   'JOSÉ LINHARES',
#   'FÁBIO SOUTO',
#   'GASTÃO VIEIRA',
#   'JOSÉ CARLOS ARAÚJO',
#   'PEDRO FERNANDES',
#   'CARLINHOS ALMEIDA',
#   'VANDER LOUBET',
#   'JORGINHO MELLO',
#   'GILMAR MACHADO',
#   'DIMAS FABIANO',
#   'SERGIO GUERRA',
#   'AFONSO HAMM',
#   'OSMAR TERRA',
#   'CIDA BORGHETTI',
#   'FÁBIO RAMALHO',
#   'FÉLIX MENDONÇA JÚNIOR',
#   'JOÃO DADO',
#   'LUIZ CARLOS',
#   'BETO MANSUR',
#   'NELSON PELLEGRINO',
#   'AFONSO FLORENCE',
#   'HÉLIO SANTOS',
#   'JUTAHY JUNIOR',
#   'NELSON MEURER',
#   'DOMINGOS NETO',
#   'VICENTE ARRUDA',
#   'SERGIO ZVEITER',
#   'JOÃO MAIA',
#   'MAURO NAZIF',
#   'ASSIS DO COUTO',
#   'REGINALDO LOPES',
#   'FELIPE BORNIER',
#   'GUILHERME CAMPOS',
#   'REINHOLD STEPHANES',
#   'PADRE JOÃO',
#   'MAURÍCIO QUINTELLA LESSA',
#   'ARNALDO JORDY',
#   'MARCIO REINALDO MOREIRA',
#   'ALMEIDA LIMA',
#   'PEDRO NOVAIS',
#   'VALADARES FILHO',
#   'JORGE CÔRTE REAL',
#   'ARTUR BRUNO',
#   'CARLOS MANATO',
#   'EDINHO ARAÚJO',
#   'JANETE ROCHA PIETÁ',
#   'EROS BIONDINI',
#   'ÁTILA LIRA',
#   'ZOINHO',
#   'HENRIQUE OLIVEIRA',
#   'LUIZ FERNANDO MACHADO',
#   'WLADIMIR COSTA',
#   'FERNANDO FERRO',
#   'REINALDO AZAMBUJA',
#   'MENDONÇA PRADO',
#   'IVAN VALENTE',
#   'LÚCIO VALE',
#   'SARNEY FILHO',
#   'ADRIAN',
#   'ELI CORREA FILHO',
#   'MÁRCIO FRANÇA',
#   'ÁTILA LINS',
#   'ANDERSON FERREIRA',
#   'NELSON PADOVANI',
#   'BETO FARO',
#   'HUGO LEAL',
#   'EDSON SILVA',
#   'MARCELO CASTRO',
#   'ZÉ SILVA',
#   'FÁBIO TRAD',
#   'DANILO CABRAL',
#   'JOVAIR ARANTES',
#   'MAGELA',
#   'CARLOS BRANDÃO',
#   'SIMÃO SESSIM',
#   'LUCIO VIEIRA LIMA',
#   'MAURO LOPES',
#   'ROGÉRIO PENINHA MENDONÇA',
#   'JOSÉ OTÁVIO GERMANO',
#   'EDINHO BEZ',
#   'ZENALDO COUTINHO',
#   'MARCELO AGUIAR',
#   'ALEXANDRE ROSO',
#   'CÉSAR HALUM',
#   'RAUL LIMA',
#   'EDIVALDO HOLANDA JUNIOR',
#   'PAULO FEIJÓ',
#   'LEONARDO VILELA',
#   'JERÔNIMO GOERGEN',
#   'WELLINGTON ROBERTO',
#   'SÉRGIO MORAES',
#   'JORGE BOEIRA',
#   'EFRAIM FILHO',
#   'DUARTE NOGUEIRA',
#   'ZÉ VIEIRA',
#   'ROSE DE FREITAS',
#   'WANDENKOLK GONÇALVES',
#   'ANGELO VANHONI',
#   'LOURIVAL MENDES',
#   'LUIS CARLOS HEINZE',
#   'MARCELO MATOS',
#   'JOSÉ AUGUSTO MAIA',
#   'RUY CARNEIRO',
#   'JANETE CAPIBERIBE',
#   'LUIZ COUTO',
#   'PAULO ABI-ACKEL',
#   'LUIZ CARLOS HAULY',
#   'ROSANE FERREIRA',
#   'GUILHERME MUSSI',
#   'SILAS CÂMARA',
#   'ALFREDO KAEFER',
#   'FLAVIANO MELO',
#   'CARLOS SAMPAIO',
#   'JOÃO ANANIAS',
#   'JÔ MORAES',
#   'LUIS TIBÉ',
#   'RUI COSTA',
#   'ALEXANDRE SANTOS',
#   'LAEL VARELLA',
#   'JOSÉ ANÍBAL',
#   'AUDIFAX',
#   'IZALCI',
#   'DEVANIR RIBEIRO',
#   'EDMAR ARRUDA',
#   'JOÃO PAULO CUNHA',
#   'DIEGO ANDRADE',
#   'CÂNDIDO VACCAREZZA',
#   'MENDONÇA FILHO',
#   'MARCO TEBALDI',
#   'HELENO SILVA',
#   'EUDES XAVIER',
#   'DANRLEI DE DEUS HINTERHOLZ',
#   'JULIO SEMEGHINI',
#   'MARCOS ROGÉRIO',
#   'PASTOR EURICO',
#   'DAVI ALCOLUMBRE',
#   'JOSÉ DE FILIPPI',
#   'PAULO CESAR QUARTIERO',
#   'HUGO NAPOLEÃO',
#   'HOMERO PEREIRA',
#   'LEONARDO QUINTÃO',
#   'SANDRO ALEX',
#   'ÂNGELO AGNOLIN',
#   'GLADSON CAMELI',
#   'ARLINDO CHINAGLIA',
#   'VALTENIR PEREIRA',
#   'TERESA SURITA',
#   'LUIZ PITIMAN',
#   'WALNEY ROCHA',
#   'EDUARDO GOMES',
#   'WALDENOR PEREIRA',
#   'ARNALDO JARDIM',
#   'WILLIAM DIB',
#   'MARCUS PESTANA',
#   'JOÃO PIZZOLATTI',
#   'VICENTE CANDIDO',
#   'ANTHONY GAROTINHO',
#   'NICE LOBÃO',
#   'PAULO PEREIRA DA SILVA',
#   'PEDRO CHAVES',
#   'JOÃO ARRUDA',
#   'ANTONIO IMBASSAHY',
#   'ROBERTO FREIRE',
#   'JÚNIOR COIMBRA',
#   'JOSÉ AIRTON',
#   'LAERCIO OLIVEIRA',
#   'HENRIQUE EDUARDO ALVES',
#   'RENZO BRAZ',
#   'MÁRCIO MACÊDO',
#   'JAIR BOLSONARO',
#   'SABINO CASTELO BRANCO',
#   'DR. ADILSON SOARES',
#   'LEONARDO PICCIANI',
#   'JEAN WYLLYS',
#   'MARCIO BITTAR',
#   'LEANDRO VILELA',
#   'AUGUSTO COUTINHO',
#   'ZEQUINHA MARINHO',
#   'PASTOR MARCO FELICIANO',
#   'DOMINGOS SÁVIO',
#   'PROFESSORA DORINHA SEABRA REZENDE',
#   'RODRIGO GARCIA',
#   'MÁRCIO MARINHO',
#   'ERIKA KOKAY',
#   'SEBASTIÃO BALA ROCHA',
#   'RUI PALMEIRA',
#   'PAULO PIMENTA',
#   'EDSON EZEQUIEL',
#   'ROBERTO TEIXEIRA',
#   'SUELI VIDIGAL',
#   'PERPÉTUA ALMEIDA',
#   'PROFESSOR SETIMO',
#   'RICARDO TRIPOLI',
#   'TIRIRICA',
#   'JOÃO LEÃO',
#   'MAURÍCIO TRINDADE',
#   'PAULO PIAU',
#   'JONAS DONIZETTE',
#   'HENRIQUE AFONSO',
#   'MÁRIO DE OLIVEIRA',
#   'LIRA MAIA',
#   'HEULER CRUVINEL',
#   'SANDRO MABEL',
#   'CARLAILE PEDROSA',
#   'LUIZ SÉRGIO',
#   'REBECCA GARCIA',
#   'ARACELY DE PAULA',
#   'JOSÉ CHAVES',
#   'CLÁUDIO PUTY',
#   'ONYX LORENZONI',
#   'BERNARDO SANTANA DE VASCONCELLOS',
#   'MOREIRA MENDES',
#   'MAURÍCIO RANDS',
#   'ONOFRE SANTO AGOSTINI',
#   'LELO COIMBRA',
#   'ROBERTO BALESTRA',
#   'VICENTINHO',
#   'TAKAYAMA',
#   'MARA GABRILLI',
#   'MARIA DO ROSÁRIO',
#   'CEZAR SILVESTRI',
#   'ANTONIO BALHMANN',
#   'JANDIRA FEGHALI',
#   'ARTHUR LIRA',
#   'MARÇAL FILHO',
#   'PAULO MALUF',
#   'GIOVANNI QUEIROZ',
#   'CARLOS MELLES',
#   'ALEXANDRE CARDOSO',
#   'DR. JORGE SILVA',
#   'JOSÉ ROCHA',
#   'GERALDO THADEU',
#   'LÁZARO BOTELHO',
#   'NATAN DONADON',
#   'PEDRO UCZAI',
#   'EDSON PIMENTA',
#   'ALESSANDRO MOLON',
#   'EDSON SANTOS'],
#  55: ['SÉRGIO MORAES',
#   'SERGIO VIDIGAL',
#   'DANILO CABRAL',
#   'JOÃO DANIEL',
#   'PAULO ABI-ACKEL',
#   'GABRIEL GUIMARÃES',
#   'ONYX LORENZONI',
#   'NELSON PELLEGRINO',
#   'ANDRÉ DE PAULA',
#   'CELSO MALDANER',
#   'JORGINHO MELLO',
#   'LEÔNIDAS CRISTINO',
#   'ROBERTO BRITTO',
#   'FÁBIO SOUSA',
#   'CÉLIO SILVEIRA',
#   'ZÉ SILVA',
#   'TADEU ALENCAR',
#   'PAULO FREIRE',
#   'AFONSO MOTTA',
#   'MIGUEL LOMBARDI',
#   'OSMAR SERRAGLIO',
#   'CESAR SOUZA',
#   'FÉLIX MENDONÇA JÚNIOR',
#   'JHONATAN DE JESUS',
#   'DR. JORGE SILVA',
#   'HERMES PARCIANELLO',
#   'JAIME MARTINS',
#   'JHC',
#   'HISSA ABRAHÃO',
#   'SILAS CÂMARA',
#   'SARNEY FILHO',
#   'DOMINGOS NETO',
#   'JOAQUIM PASSARINHO',
#   'ÁTILA LIRA',
#   'CARLOS MARUN',
#   'LELO COIMBRA',
#   'SUBTENENTE GONZAGA',
#   'NEWTON CARDOSO JR',
#   'HILDO ROCHA',
#   'RODRIGO MAIA',
#   'ANDERSON FERREIRA',
#   'MARCELO CASTRO',
#   'RENATO MOLLING',
#   'AROLDE DE OLIVEIRA',
#   'REMÍDIO MONAI',
#   'RODRIGO DE CASTRO',
#   'ALEXANDRE VALLE',
#   'ODORICO MONTEIRO',
#   'ZECA CAVALCANTI',
#   'DÉCIO LIMA',
#   'RICARDO BARROS',
#   'MARIANA CARVALHO',
#   'EVANDRO GUSSI',
#   'MARCELO ÁLVARO ANTÔNIO',
#   'MARIA HELENA',
#   'JUNIOR MARRECA',
#   'ROBERTO DE LUCENA',
#   'PAULO MAGALHÃES',
#   'DAMIÃO FELICIANO',
#   'LINDOMAR GARÇON',
#   'DANILO FORTE',
#   'RICARDO IZAR',
#   'MENDONÇA FILHO',
#   'GILBERTO NASCIMENTO',
#   'EZEQUIEL TEIXEIRA',
#   'JOÃO MARCELO SOUZA',
#   'MIRO TEIXEIRA',
#   'JOSÉ OTÁVIO GERMANO',
#   'ESPERIDIÃO AMIN',
#   'CAPITÃO AUGUSTO',
#   'FERNANDO COELHO FILHO',
#   'LUIZ CLÁUDIO',
#   'MARCELO BELINATI',
#   'OSMAR TERRA',
#   'ANDRÉ FUFUCA',
#   'NELSON MARQUEZELLI',
#   'RONALDO NOGUEIRA',
#   'PEDRO VILELA',
#   'FABIO GARCIA',
#   'WOLNEY QUEIROZ',
#   'PEDRO FERNANDES',
#   'WILSON FILHO',
#   'VENEZIANO VITAL DO RÊGO',
#   'WALDIR MARANHÃO',
#   'ALIEL MACHADO',
#   'MILTON MONTI',
#   'LEOPOLDO MEYER',
#   'BRUNNY',
#   'ALTINEU CÔRTES',
#   'PAULO PIMENTA',
#   'GIVALDO CARIMBÃO',
#   'CELSO PANSERA',
#   'EDMILSON RODRIGUES',
#   'MAJOR OLIMPIO',
#   'BETO FARO',
#   'RAQUEL MUNIZ',
#   'ALEX CANZIANI',
#   'CARLOS ANDRADE',
#   'MARCOS REATEGUI',
#   'ADILTON SACHETTI',
#   'DOMINGOS SÁVIO',
#   'PAULÃO',
#   'JÚLIA MARINHO',
#   'ANTONIO IMBASSAHY',
#   'JOÃO ARRUDA',
#   'ALBERTO FRAGA',
#   'IRAJÁ ABREU',
#   'INDIO DA COSTA',
#   'MAURO LOPES',
#   'MÁRCIO BIOLCHI',
#   'MAGDA MOFATTO',
#   'DELEY',
#   'JULIO LOPES',
#   'CARLOS ZARATTINI',
#   'CÉSAR MESSIAS',
#   'PROFESSORA DORINHA SEABRA REZENDE',
#   'JÚLIO CESAR',
#   'CARLOS GOMES',
#   'GENECIAS NORONHA',
#   'REGINALDO LOPES',
#   'PASTOR EURICO',
#   'JANETE CAPIBERIBE',
#   'JOSUÉ BENGTSON',
#   'JÚLIO DELGADO',
#   'NILSON LEITÃO',
#   'ZÉ GERALDO',
#   'JÔ MORAES',
#   'DIEGO GARCIA',
#   'ROGÉRIO MARINHO',
#   'CAIO NARCIO',
#   'CARLOS MANATO',
#   'LAERTE BESSA',
#   'DIMAS FABIANO',
#   'JAIR BOLSONARO',
#   'EDIO LOPES',
#   'LINCOLN PORTELA',
#   'PR. MARCO FELICIANO',
#   'ARTHUR OLIVEIRA MAIA',
#   'VICTOR MENDES',
#   'CELSO RUSSOMANNO',
#   'JARBAS VASCONCELOS',
#   'JOÃO CAMPOS',
#   'JOSÉ GUIMARÃES',
#   'IZALCI',
#   'MARCIO MONTEIRO',
#   'NILSON PINTO',
#   'SAMUEL MOREIRA',
#   'ADAIL CARNEIRO',
#   'PEPE VARGAS',
#   'ENIO VERRI',
#   'SARAIVA FELIPE',
#   'BENJAMIN MARANHÃO',
#   'TONINHO PINHEIRO',
#   'OTAVIO LEITE',
#   'BRUNA FURLAN',
#   'EDUARDO BOLSONARO',
#   'VICENTINHO JÚNIOR',
#   'MARCOS MONTES',
#   'TAKAYAMA',
#   'PADRE JOÃO',
#   'MORONI TORGAN',
#   'JORGE TADEU MUDALEN',
#   'LUIZ CARLOS RAMOS ',
#   'MANDETTA',
#   'HUGO MOTTA',
#   'AELTON FREITAS',
#   'ZENAIDE MAIA',
#   'PEDRO PAULO',
#   'RUBENS PEREIRA JÚNIOR',
#   'ARTHUR LIRA',
#   'FAUSTO PINATO',
#   'SILVIO TORRES',
#   'LAUDIVIO CARVALHO',
#   'ALEX MANENTE',
#   'RODRIGO GARCIA',
#   'GLAUBER BRAGA',
#   'CHICO ALENCAR',
#   'BRUNO ARAÚJO',
#   'RONALDO BENEDET',
#   'BETINHO GOMES',
#   'ZECA DO PT',
#   'EDUARDO BARBOSA',
#   'BENEDITA DA SILVA',
#   'JOSIAS GOMES',
#   'CAETANO',
#   'JEAN WYLLYS',
#   'NELSON MARCHEZAN JUNIOR',
#   'JOSÉ CARLOS ARAÚJO',
#   'ARNALDO FARIA DE SÁ',
#   'VALMIR ASSUNÇÃO',
#   'CABO DACIOLO',
#   'HEITOR SCHUCH',
#   'ROSANGELA GOMES',
#   'LUIZ FERNANDO FARIA',
#   'PASTOR FRANKLIN',
#   'FELIPE CARRERAS',
#   'AFONSO HAMM',
#   'MAURÍCIO QUINTELLA LESSA',
#   'GUILHERME MUSSI',
#   'RODRIGO MARTINS',
#   'CARLOS BEZERRA',
#   'DULCE MIRANDA',
#   'JOVAIR ARANTES',
#   'ANDRÉ FIGUEIREDO',
#   'ANTONIO BRITO',
#   'JÉSSICA SALES',
#   'NILTO TATTO',
#   'VALDIR COLATTO',
#   'COVATTI FILHO',
#   'MÁRIO NEGROMONTE JR.',
#   'JOSÉ PRIANTE',
#   'PAES LANDIM',
#   'RAIMUNDO GOMES DE MATOS',
#   'ANÍBAL GOMES',
#   'MAX FILHO',
#   'LAERCIO OLIVEIRA',
#   'EXPEDITO NETTO',
#   'BONIFÁCIO DE ANDRADA',
#   'JOÃO PAULO KLEINÜBING',
#   'CACÁ LEÃO',
#   'SEBASTIÃO OLIVEIRA',
#   'VICENTE CANDIDO',
#   'CABO SABINO',
#   'TENENTE LÚCIO',
#   'LÁZARO BOTELHO',
#   'MARCELO ARO',
#   'SORAYA SANTOS',
#   'MARCO TEBALDI',
#   'ANA PERUGINI',
#   'EZEQUIEL FONSECA',
#   'ROBERTO SALES',
#   'ROGÉRIO ROSSO',
#   'JONY MARCOS',
#   'ROSSONI',
#   'DANIEL ALMEIDA',
#   'CRISTIANE BRASIL',
#   'PATRUS ANANIAS',
#   'TEREZA CRISTINA',
#   'CARLOS HENRIQUE GAGUIM',
#   'IVAN VALENTE',
#   'ARNON BEZERRA',
#   'ODELMO LEÃO',
#   'ALFREDO NASCIMENTO',
#   'RENZO BRAZ',
#   'PAUDERNEY AVELINO',
#   'EDUARDO DA FONTE',
#   'IRMÃO LAZARO',
#   'SILVIO COSTA',
#   'ALICE PORTUGAL',
#   'MISSIONÁRIO JOSÉ OLIMPIO',
#   'SIBÁ MACHADO',
#   'MARINALDO ROSENDO',
#   'VINICIUS GURGEL',
#   'LUIZ NISHIMORI',
#   'MIGUEL CORRÊA',
#   'TIRIRICA',
#   'DELEGADO EDSON MOREIRA',
#   'JOSÉ REINALDO',
#   'EFRAIM FILHO',
#   'LUCIANA SANTOS',
#   'FRANCISCO CHAPADINHA',
#   'MARINHA RAUPP',
#   'EVANDRO ROMAN',
#   'CÉSAR HALUM',
#   'ORLANDO SILVA',
#   'JOÃO DERLY',
#   'PAULO PEREIRA DA SILVA',
#   'CLEBER VERDE',
#   'EDMAR ARRUDA',
#   'LUIZ CARLOS BUSATO',
#   'SANDRO ALEX',
#   'GIVALDO VIEIRA',
#   'DARCÍSIO PERONDI',
#   'FLAVINHO',
#   'ZÉ CARLOS',
#   'PEDRO CHAVES',
#   'FELIPE BORNIER',
#   'DELEGADO ÉDER MAURO',
#   'VANDER LOUBET',
#   'MARCUS PESTANA',
#   'ADALBERTO CAVALCANTI',
#   'LEANDRE',
#   'LUCIANO DUCCI',
#   'DILCEU SPERAFICO',
#   'SÁGUAS MORAES',
#   'TONINHO WANDSCHEER',
#   'ANTONIO BULHÕES',
#   'DELEGADO WALDIR',
#   'CARLOS MELLES',
#   'MOSES RODRIGUES',
#   'JOÃO RODRIGUES',
#   'GONZAGA PATRIOTA',
#   'TIA ERON',
#   'ROCHA',
#   'BACELAR',
#   'FÁBIO RAMALHO',
#   'MARCOS SOARES',
#   'VICENTINHO',
#   'PAULO MALUF',
#   'PAULO FOLETTO',
#   'LUIZA ERUNDINA',
#   'LUCAS VERGILIO',
#   'KEIKO OTA',
#   'LEO DE BRITO',
#   'LUCIO VIEIRA LIMA',
#   'MARGARIDA SALOMÃO',
#   'JORGE BOEIRA',
#   'JANDIRA FEGHALI',
#   'ROBERTO ALVES',
#   'WELLINGTON ROBERTO',
#   'MAURO MARIANI',
#   'ARTHUR VIRGÍLIO BISNETO',
#   'FRANCISCO FLORIANO',
#   'KAIO MANIÇOBA',
#   'RONALDO FONSECA',
#   'JOÃO CARLOS BACELAR',
#   'MANOEL JUNIOR',
#   'JERÔNIMO GOERGEN',
#   'FELIPE MAIA',
#   'MARX BELTRÃO ',
#   'ROBERTO BALESTRA',
#   'VALMIR PRASCIDELLI',
#   'EDUARDO CUNHA',
#   'HUGO LEAL',
#   'PROFESSOR VICTÓRIO GALLI',
#   'DÂMINA PEREIRA',
#   'JUTAHY JUNIOR',
#   'JOÃO FERNANDO COUTINHO',
#   'ERIKA KOKAY',
#   'RONALDO LESSA',
#   'JOÃO CASTELO',
#   'AUGUSTO CARVALHO',
#   'ELMAR NASCIMENTO',
#   'RICARDO TEOBALDO ',
#   'WLADIMIR COSTA',
#   'MARCO MAIA',
#   'CONCEIÇÃO SAMPAIO',
#   'SERGIO ZVEITER',
#   'GOULART',
#   'VITOR VALIM',
#   'ÁTILA LINS',
#   'RENATA ABREU',
#   'FÁBIO FARIA',
#   'LUIZIANNE LINS',
#   'MARCUS VICENTE',
#   'MARCON',
#   'HÉLIO LEITE',
#   'JORGE CÔRTE REAL',
#   'ALUISIO MENDES',
#   'MACEDO',
#   'CLARISSA GAROTINHO',
#   'ALESSANDRO MOLON',
#   'CHICO LOPES',
#   'JOÃO PAULO PAPA',
#   'CARLOS SAMPAIO',
#   'LUIZ SÉRGIO',
#   'BENITO GAMA',
#   'LUIS CARLOS HEINZE',
#   'ROGÉRIO PENINHA MENDONÇA',
#   'ULDURICO JUNIOR',
#   'BEBETO',
#   'LEONARDO PICCIANI',
#   'FERNANDO FRANCISCHINI',
#   'ELCIONE BARBALHO',
#   'CAPITÃO FÁBIO ABREU',
#   'ALBERTO FILHO',
#   'HIRAN GONÇALVES',
#   'ALAN RICK',
#   'BILAC PINTO',
#   'MARCO ANTÔNIO CABRAL',
#   'CLAUDIO CAJADO',
#   'ANTÔNIO JÁCOME',
#   'ALEXANDRE BALDY',
#   'IRACEMA PORTELLA',
#   'NILTON CAPIXABA',
#   'PEDRO CUNHA LIMA',
#   'JOZI ROCHA',
#   'POMPEO DE MATTOS',
#   'ODAIR CUNHA',
#   'RONALDO CARLETTO',
#   'ARNALDO JARDIM',
#   'RÔMULO GOUVEIA',
#   'ANDRE MOURA',
#   'JOÃO GUALBERTO',
#   'ALEXANDRE LEITE',
#   'FLORIANO PESARO',
#   'HENRIQUE FONTANA',
#   'SÓSTENES CAVALCANTE',
#   'JOSE STÉDILE',
#   'WALDENOR PEREIRA',
#   'MARCOS ROTTA',
#   'BALEIA ROSSI',
#   'JUSCELINO FILHO',
#   'GEOVANIA DE SÁ',
#   'SÉRGIO REIS',
#   'PROFESSORA MARCIVANIA',
#   'DANIEL VILELA',
#   'MIGUEL HADDAD',
#   'JOSÉ NUNES',
#   'GERALDO RESENDE',
#   'ALCEU MOREIRA',
#   'MARCOS ROGÉRIO',
#   'CARMEN ZANOTTO',
#   'JEFFERSON CAMPOS',
#   'FLÁVIA MORAIS',
#   'AFONSO FLORENCE',
#   'MARA GABRILLI',
#   'RICARDO TRIPOLI',
#   'FABIANO HORTA',
#   'ASSIS CARVALHO',
#   'JOSI NUNES',
#   'REJANE DIAS',
#   'JOSÉ MENTOR',
#   'WELITON PRADO',
#   'AUREO',
#   'SHÉRIDAN',
#   'ZECA DIRCEU',
#   'JOSÉ CARLOS ALELUIA',
#   'ANTONIO BALHMANN',
#   'LUIZ LAURO FILHO',
#   'LEONARDO MONTEIRO',
#   'WEVERTON ROCHA',
#   'CÍCERO ALMEIDA',
#   'HERÁCLITO FORTES',
#   'HEULER CRUVINEL',
#   'THIAGO PEIXOTO',
#   'WASHINGTON REIS',
#   'STEFANO AGUIAR',
#   'ALFREDO KAEFER',
#   'EVAIR DE MELO',
#   'BETO MANSUR',
#   'VITOR LIPPI',
#   'DR. JOÃO',
#   'ARNALDO JORDY',
#   'RAFAEL MOTTA',
#   'BOHN GASS',
#   'EDINHO ARAÚJO',
#   'JOSÉ AIRTON CIRILO',
#   'DIEGO ANDRADE',
#   'SÉRGIO BRITO',
#   'GORETE PEREIRA',
#   'GIOVANI CHERINI',
#   'MARCELO MATOS',
#   'JOSÉ ROCHA',
#   'HELDER SALOMÃO',
#   'VANDERLEI MACRIS',
#   'PEDRO UCZAI',
#   'FABIO REIS',
#   'DUARTE NOGUEIRA',
#   'LEONARDO QUINTÃO',
#   'MÁRIO HERINGER',
#   'GEORGE HILTON',
#   'HERCULANO PASSOS',
#   'ABEL MESQUITA JR.',
#   'RONALDO MARTINS',
#   'ADELSON BARRETO',
#   'MARCOS ABRÃO',
#   'CHRISTIANE DE SOUZA YARED',
#   'MARCIO ALVINO',
#   'FÁBIO MITIDIERI',
#   'RUBENS OTONI',
#   'BETO SALAME',
#   'MOEMA GRAMACHO',
#   'LÚCIO VALE',
#   'MISAEL VARELLA',
#   'PAULO TEIXEIRA',
#   'NELSON MEURER',
#   'DANIEL COELHO',
#   'DAGOBERTO',
#   'ASSIS DO COUTO',
#   'LUCIO MOSQUINI',
#   'FERNANDO JORDÃO',
#   'BRUNO COVAS',
#   'RODRIGO PACHECO',
#   'DR. SINVAL MALHEIROS',
#   'GIOVANI FELTES',
#   'MARCELO SQUASSONI',
#   'LUIS TIBÉ',
#   'MARIA DO ROSÁRIO',
#   'ALEXANDRE SERFIOTIS',
#   'SIMÃO SESSIM',
#   'AGUINALDO RIBEIRO',
#   'SERGIO SOUZA ',
#   'BETO ROSADO',
#   'ARLINDO CHINAGLIA',
#   'VINICIUS CARVALHO',
#   'PAULO AZI',
#   'ANDRES SANCHEZ',
#   'LUIZ COUTO',
#   'JORGE SOLLA',
#   'RONEY NEMER',
#   'ELIZIANE GAMA',
#   'EROS BIONDINI',
#   'VALTENIR PEREIRA',
#   'RUBENS BUENO',
#   'PAULO FEIJÓ',
#   'MÁRCIO MARINHO',
#   'EDUARDO CURY',
#   'ANGELIM',
#   'SIMONE MORGADO',
#   'LUIZ CARLOS HAULY',
#   'ELI CORRÊA FILHO',
#   'GIACOBO',
#   "CHICO D'ANGELO",
#   'DANRLEI DE DEUS HINTERHOLZ',
#   'VALADARES FILHO',
#   'ROBERTO GÓES',
#   'ANDRÉ ABDON',
#   'ERIVELTON SANTANA',
#   'GIUSEPPE VECCI',
#   'WALTER ALVES',
#   'CABUÇU BORGES',
#   'FLAVIANO MELO']}

# %% [markdown]
# #### Conjunto de arestas

# %%
tramitacoes_deps = pd.DataFrame(columns=['deputado', 'idProposicao', 'numlegislatura'])

for leg in legislaturas.values():
    
    for dep in deps_legs[leg]:
        
        tram_dep = deepcopy(tramitacoes_aborto[tramitacoes_aborto['andamento_tramitacao_descricao'].str.upper().str.contains(dep.upper())])
        
        tram_dep['deputado'] = dep
        
        tramitacoes_deps = tramitacoes_deps.append(tram_dep[['deputado', 'idProposicao', 'numlegislatura']])

# %%
tramitacoes_deps = tramitacoes_deps.drop_duplicates().reset_index(drop=True) # Desconsiderando relação de um deputado com ele mesmo
tramitacoes_deps.head()
# Out:
#        deputado idProposicao  numlegislatura
# 0   IRINY LOPES       281681            52.0
# 1   EDNA MACEDO        18716            52.0
# 2    DRA. CLAIR        18716            52.0
# 3  LUIZ BASSUMA        16299            53.0
# 4  LUIZ BASSUMA       345103            53.0

# %%
relacoes = pd.merge(tramitacoes_deps, tramitacoes_deps, on=['numlegislatura', 'idProposicao'])
relacoes.head()
# Out:
#         deputado_x idProposicao  numlegislatura       deputado_y
# 0      IRINY LOPES       281681            52.0      IRINY LOPES
# 1      IRINY LOPES       281681            52.0  OSMÂNIO PEREIRA
# 2      IRINY LOPES       281681            52.0    NILTON BAIANO
# 3  OSMÂNIO PEREIRA       281681            52.0      IRINY LOPES
# 4  OSMÂNIO PEREIRA       281681            52.0  OSMÂNIO PEREIRA

# %%
print('Número de arestas na rede: ', len(relacoes))
# Out:
# Número de arestas na rede:  5848

# %% [markdown]
# ### Representação Gráfica

# %%
ranking = {}

# %%
# Escolher a legislatura
leg = 55

# %%
import networkx as nx

G = nx.from_pandas_edgelist(relacoes[relacoes['numlegislatura'] == leg], 'deputado_x', 'deputado_y')

print('\nLegislatura   : ', leg, 
      '\nNº de nós     : ', len(G.nodes), 
      '\nNº de arestas : ', len(G.edges))
# Out:
# Legislatura   :  55
# Nº de nós     :  47
# Nº de arestas :  652

# %%
def create_viz_network(G):

    # create node trace:
    node_trace = go.Scatter(x = [], y = [], 
                            text = [], mode = 'markers',
                            hoverinfo='text',
                            marker = dict(
                                showscale = True,
                                colorscale = 'YIGnBu',
                                reversescale = True,
                                color = [],
                                size = 10,
                                colorbar = dict(
                                    thickness = 15,
                                    title = 'Número de conexões',
                                    xanchor = 'left',
                                    titleside = 'right'),
                                line = dict(width = 1)))

    # set node positions
    pos = nx.spring_layout(G)
    for node in G.nodes():
        G.node[node]['pos']= pos[node]

    for node in G.nodes():
        x, y = G.node[node]['pos']
        node_trace['x'].append(x)
        node_trace['y'].append(y)

    # create edge trace:
    edge_trace = go.Scatter(x = [], y = [], text = [],
                         line = dict(width = 1, color = '#888'),
                         mode = 'lines')

    for edge in G.edges():
        x0, y0 = G.node[edge[0]]['pos']
        x1, y1 = G.node[edge[1]]['pos']
        edge_trace['x'] += [x0, x1, None]
        edge_trace['y'] += [y0, y1, None]
        #edge_trace['text'] += str(matrix.loc[edge[0], edge[1]])[:5]

    for node, adjacencies in list(G.adjacency()):
        node_trace['marker']['color'].append(len(adjacencies))
        node_info = '# de conexões: '+str(len(adjacencies))
        node_trace['text'].append(node + '<br>' + node_info)

    layout = go.Layout(
                titlefont=dict(size=16),
                showlegend=False,
                hovermode='closest',
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
    
    fig = go.Figure(data=[edge_trace, node_trace], layout=layout)
    offline.iplot(fig, filename='networkx')
    
    graus = [(node, len(adjacencies)) for node, adjacencies in list(G.adjacency())]
    graus.sort(key=lambda x: x[1], reverse=True)
    
    return pd.DataFrame(graus, columns=['Deputado(a)', 'Grau']).set_index('Deputado(a)')

# %%
ranking[leg] = create_viz_network(G)
ranking[leg].head(10)
# Out:
# <div id="57045aa2-bec0-4d1c-97e0-05e08ed07b4a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("57045aa2-bec0-4d1c-97e0-05e08ed07b4a", [{"mode": "lines", "type": "scatter", "text": [], "y": [-0.04679658916347503, -0.029836103339268207, null, -0.04679658916347503, -0.00020279835984312794, null, -0.04679658916347503, 0.010085242782709659, null, -0.04679658916347503, -0.029348431579712127, null, -0.04679658916347503, -0.005513742616951081, null, -0.04679658916347503, -0.04679658916347503, null, -0.04679658916347503, -0.04420710983800348, null, -0.04679658916347503, 0.05547287232999798, null, -0.04679658916347503, -0.01735656590005242, null, -0.04679658916347503, -0.0243502585233111, null, -0.04679658916347503, 0.036309296934267314, null, -0.04679658916347503, -0.016312438995024246, null, -0.04679658916347503, -0.016242270133442958, null, -0.04679658916347503, -0.0025597472494063743, null, -0.04679658916347503, -0.03367531904242602, null, -0.04679658916347503, -0.041074396644536625, null, -0.04679658916347503, 0.006676434231556068, null, -0.04679658916347503, 0.0038446566772540086, null, -0.04679658916347503, -0.15642637393591718, null, -0.04679658916347503, -0.011436404118849976, null, -0.04679658916347503, -0.024586167779879153, null, -0.04679658916347503, -0.01409722609087402, null, -0.04679658916347503, -0.05221854538504726, null, -0.04679658916347503, -0.1749236625409946, null, -0.04679658916347503, 0.009109628269262197, null, -0.04679658916347503, -0.00021343004414648025, null, -0.04679658916347503, 0.019002199577066843, null, -0.04679658916347503, 0.02324166920938478, null, -0.04679658916347503, 0.028298360948516454, null, -0.04679658916347503, 0.01176016292566362, null, -0.04679658916347503, 0.02874307788634663, null, -0.04679658916347503, 0.029582236373831516, null, -0.04679658916347503, -0.03171586873706627, null, -0.04679658916347503, -0.012080411042969811, null, -0.04679658916347503, 0.012065902116266023, null, -0.04679658916347503, 0.023945932792387402, null, -0.04679658916347503, 0.029961112726042193, null, -0.1749236625409946, -0.05221854538504726, null, -0.1749236625409946, -0.15642637393591718, null, -0.1749236625409946, -0.1749236625409946, null, 0.010085242782709659, -0.029836103339268207, null, 0.010085242782709659, -0.00020279835984312794, null, 0.010085242782709659, 0.010085242782709659, null, 0.010085242782709659, -0.029348431579712127, null, 0.010085242782709659, -0.005513742616951081, null, 0.010085242782709659, -0.04420710983800348, null, 0.010085242782709659, 0.05547287232999798, null, 0.010085242782709659, -0.01735656590005242, null, 0.010085242782709659, -0.0243502585233111, null, 0.010085242782709659, 0.036309296934267314, null, 0.010085242782709659, -0.016312438995024246, null, 0.010085242782709659, -0.016242270133442958, null, 0.010085242782709659, -0.0025597472494063743, null, 0.010085242782709659, -0.03367531904242602, null, 0.010085242782709659, -0.041074396644536625, null, 0.010085242782709659, 0.006676434231556068, null, 0.010085242782709659, 0.0038446566772540086, null, 0.010085242782709659, -0.011436404118849976, null, 0.010085242782709659, -0.024586167779879153, null, 0.010085242782709659, -0.01409722609087402, null, 0.010085242782709659, -0.05221854538504726, null, 0.010085242782709659, 0.009109628269262197, null, 0.010085242782709659, -0.00021343004414648025, null, 0.010085242782709659, 0.019002199577066843, null, 0.010085242782709659, 0.02324166920938478, null, 0.010085242782709659, 0.028298360948516454, null, 0.010085242782709659, 0.01176016292566362, null, 0.010085242782709659, 0.02874307788634663, null, 0.010085242782709659, 0.029582236373831516, null, 0.010085242782709659, -0.03171586873706627, null, 0.010085242782709659, -0.012080411042969811, null, 0.010085242782709659, 0.012065902116266023, null,  ...
#                   Grau
# Deputado(a)
# FLAVINHO            38
# MARCOS ROGÉRIO      37
# JOÃO CAMPOS         37
# GIVALDO CARIMBÃO    36
# TADEU ALENCAR       35
# IVAN VALENTE        35
# REGINALDO LOPES     35
# ESPERIDIÃO AMIN     35
# EVANDRO GUSSI       35
# CAPITÃO AUGUSTO     35

# %%
test = deepcopy(ranking)

# %%
ranking = deepcopy(test)

while leg > 52:
    ranking[leg-1] = pd.concat([ranking[leg], ranking[leg-1]], axis=1)
    leg -= 1

# %%
ranking[52].columns = [52, 53, 54, 55]

ranking[52].fillna(0)
# Out:
#                                  52    53    54    55
# AFONSO FLORENCE                 0.0  12.0   0.0   0.0
# ALBERTO FILHO                   0.0   2.0   0.0   0.0
# ALCENI GUERRA                   0.0   0.0   5.0   0.0
# ALCEU MOREIRA                  35.0   0.0   0.0   0.0
# ALINE CORRÊA                    0.0   0.0  55.0   0.0
# ALMERINDA DE CARVALHO           0.0   0.0   0.0   6.0
# ANDERSON FERREIRA               1.0   0.0   0.0   0.0
# ANDRE MOURA                     0.0   1.0   0.0   0.0
# ANDRÉ ZACHAROW                  0.0   0.0   0.0   9.0
# ANGELA GUADAGNIN                0.0   0.0   0.0  16.0
# ANTONIO CARLOS BISCAIA          0.0   0.0  55.0   1.0
# ANTONIO CARLOS MAGALHÃES NETO   0.0   0.0   0.0   9.0
# ARLINDO CHINAGLIA               0.0   0.0  14.0   0.0
# ARMANDO ABÍLIO                  0.0   0.0  55.0   0.0
# ARNALDO FARIA DE SÁ            35.0   6.0   0.0   0.0
# ASSIS CARVALHO                  0.0  12.0   0.0   0.0
# BACELAR                        35.0   0.0   0.0   0.0
# BRUNO COVAS                    35.0   0.0   0.0   0.0
# CAPITÃO AUGUSTO                35.0   0.0   0.0   0.0
# CARLOS ABICALIL                 0.0   0.0  55.0   0.0
# CARLOS BEZERRA                  0.0   6.0   3.0   0.0
# CARLOS SANTANA                  0.0   0.0  55.0   0.0
# CHICO ALENCAR                  35.0   0.0   0.0   0.0
# CIDA DIOGO                      0.0   0.0  58.0   0.0
# CLEBER VERDE                    0.0   1.0   0.0   0.0
# CLÁUDIO PUTY                    0.0  12.0   0.0   0.0
# COSTA FERREIRA                  0.0   0.0  55.0   0.0
# COVATTI FILHO                  35.0   0.0   0.0   0.0
# CRISTIANE BRASIL               35.0   0.0   0.0   0.0
# DARCÍSIO PERONDI                1.0   0.0  62.0   8.0
# ...                             ...   ...   ...   ...
# REGIS DE OLIVEIRA               0.0   0.0  56.0   0.0
# RIBAMAR ALVES                   0.0   0.0   3.0   0.0
# RICARDO IZAR                    0.0   6.0   0.0   0.0
# RITA CAMATA                     0.0   0.0  62.0   0.0
# ROBERTO BRITTO                  0.0   0.0  55.0   0.0
# ROBERTO DE LUCENA               0.0   1.0   0.0   0.0
# ROBERTO GOUVEIA                 0.0   0.0   0.0   8.0
# ROCHA                           0.0   0.0  56.0   0.0
# RODRIGO MAIA                   35.0   0.0  55.0   0.0
# RODRIGO PACHECO                35.0   0.0   0.0   0.0
# RONALDO CAIADO                  0.0   0.0  55.0   0.0
# RONALDO FONSECA                35.0   0.0   0.0   0.0
# RUBENS PEREIRA JÚNIOR          35.0   0.0   0.0   0.0
# RÔMULO GOUVEIA                  1.0   0.0   0.0   0.0
# SANDRA ROSADO                   0.0   0.0   0.0  10.0
# SERGIO ZVEITER                  0.0  12.0   0.0   0.0
# SEVERINO CAVALCANTI             0.0   0.0   0.0   2.0
# SILVINHO PECCIOLI               0.0   0.0  55.0   0.0
# SILVIO COSTA                    0.0   6.0   0.0   0.0
# SIMÃO SESSIM                    0.0   0.0  55.0   6.0
# SOLANGE ALMEIDA                 0.0   0.0  62.0   0.0
# SUELI VIDIGAL                   0.0   1.0  14.0   0.0
# SÓSTENES CAVALCANTE             2.0   0.0   0.0   0.0
# TADEU ALENCAR                  35.0   0.0   0.0   0.0
# TAKAYAMA                        1.0   1.0  63.0   1.0
# TONHA MAGALHÃES                 0.0   0.0  55.0   0.0
# VALTENIR PEREIRA                0.0   0.0  55.0   0.0
# VICENTE ARRUDA                  0.0   0.0  55.0   0.0
# VICENTINHO                      0.0   0.0  55.0   0.0
# ÍRIS DE ARAÚJO                  0.0   0.0  55.0   0.0
#
# [154 rows x 4 columns]

# %%
a = False
b = pd.DataFrame([1, 2, 3])
a=b

# %%
c=[a, b]
list(filter(lambda x : type(x) == pd.core.frame.DataFrame, c))[0]
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
type(b) == pd.core.frame.DataFrame
# Out:
# True
